# %%
import pandas as pd
import warnings # Suppress all warnings

# %%
import warnings # Suppress all warnings 
warnings.filterwarnings("ignore")
data = '../data/raw/DisasterDeclarationsSummaries.csv'
raw_df = pd.read_csv(data)

# %%
initial_df = raw_df.copy()

# %%
initial_df.drop(columns = ['femaDeclarationString', 'declarationType', 'declarationDate', 'declarationTitle', 'ihProgramDeclared', 
                           'iaProgramDeclared', 'placeCode', 'declarationRequestNumber', 'lastIAFilingDate', 'incidentId', 
                           'region', 'designatedIncidentTypes', 'lastRefresh', 'hash', 'id', 'paProgramDeclared', 'hmProgramDeclared',
                          'incidentBeginDate', 'incidentEndDate', 'disasterCloseoutDate', 'tribalRequest', 'fipsStateCode', 'fipsCountyCode'],
                inplace=True)

# %%
filtered_df = initial_df.copy()
filtered_df = initial_df[initial_df['fyDeclared'] >= 2000]
filtered_df
# Out:
#        disasterNumber state  fyDeclared  incidentType       designatedArea
# 0                5530    NV        2024          Fire      Washoe (County)
# 1                5529    OR        2024          Fire  Washington (County)
# 2                5528    OR        2024          Fire   Jefferson (County)
# 3                5527    OR        2024          Fire   Deschutes (County)
# 4                5526    CO        2024          Fire   Jefferson (County)
# ...               ...   ...         ...           ...                  ...
# 51574            1305    NH        2000     Hurricane     Belknap (County)
# 51575            1305    NH        2000     Hurricane    Cheshire (County)
# 51576            1305    NH        2000     Hurricane     Grafton (County)
# 51577            1304    AZ        2000  Severe Storm     Cochise (County)
# 51578            1304    AZ        2000  Severe Storm    Maricopa (County)
#
# [47804 rows x 5 columns]

# %%
filtered_df['incidentType'].value_counts()
# Out:
# incidentType
# Severe Storm           14190
# Hurricane              12051
# Biological              7857
# Flood                   3775
# Fire                    2930
# Severe Ice Storm        2746
# Snowstorm               1408
# Tropical Storm          1046
# Coastal Storm            551
# Tornado                  434
# Other                    298
# Earthquake               186
# Winter Storm             117
# Freezing                  77
# Typhoon                   58
# Mud/Landslide             40
# Dam/Levee Break           11
# Chemical                   9
# Tsunami                    9
# Terrorist                  5
# Straight-Line Winds        2
# Volcanic Eruption          2
# Toxic Substances           1
# Drought                    1
# Name: count, dtype: int64

# %%
filtered_df.rename(columns = {'fyDeclared': 'year'}, inplace = True)

# %%
filtered_df
# Out:
#        disasterNumber state  year  incidentType       designatedArea
# 0                5530    NV  2024          Fire      Washoe (County)
# 1                5529    OR  2024          Fire  Washington (County)
# 2                5528    OR  2024          Fire   Jefferson (County)
# 3                5527    OR  2024          Fire   Deschutes (County)
# 4                5526    CO  2024          Fire   Jefferson (County)
# ...               ...   ...   ...           ...                  ...
# 51574            1305    NH  2000     Hurricane     Belknap (County)
# 51575            1305    NH  2000     Hurricane    Cheshire (County)
# 51576            1305    NH  2000     Hurricane     Grafton (County)
# 51577            1304    AZ  2000  Severe Storm     Cochise (County)
# 51578            1304    AZ  2000  Severe Storm    Maricopa (County)
#
# [47804 rows x 5 columns]

# %%
filtered_df['year'].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014,
#        2013, 2012, 2009, 2006, 2011, 2010, 2003, 2008, 2025, 2007, 2005,
#        2004, 2002, 2001, 2000])

# %%
def clean_designated_area(area_name, state_name):
    # Remove parenthesis
    area_name = area_name.replace('(', '').replace(')', '').strip()
    # Add the state (from the state column)
    formatted_area = f"{area_name}, {state_name}"
    return formatted_area

# Apply the cleaning function on the 'designatedArea' and 'state' columns
filtered_df['disaster_area'] = filtered_df.apply(lambda row: clean_designated_area(row['designatedArea'], row['state']), axis=1)

filtered_df
# Out:
#        disasterNumber state  year  incidentType       designatedArea  \
# 0                5530    NV  2024          Fire      Washoe (County)
# 1                5529    OR  2024          Fire  Washington (County)
# 2                5528    OR  2024          Fire   Jefferson (County)
# 3                5527    OR  2024          Fire   Deschutes (County)
# 4                5526    CO  2024          Fire   Jefferson (County)
# ...               ...   ...   ...           ...                  ...
# 51574            1305    NH  2000     Hurricane     Belknap (County)
# 51575            1305    NH  2000     Hurricane    Cheshire (County)
# 51576            1305    NH  2000     Hurricane     Grafton (County)
# 51577            1304    AZ  2000  Severe Storm     Cochise (County)
# 51578            1304    AZ  2000  Severe Storm    Maricopa (County)
#
#                disaster_area
# 0          Washoe County, NV
# 1      Washington County, OR
# 2       Jefferson County, OR
# 3       Deschutes County, OR
# 4       Jefferson County, CO
# ...                      ...
# 51574     Belknap County, NH
# 51575    Cheshire County, NH
# 51576     Grafton County, NH
# 51577     Cochise County, AZ
# 51578    Maricopa County, AZ
#
# [47804 rows x 6 columns]

# %%
filtered_df.isnull().sum()
# Out:
# disasterNumber    0
# state             0
# year              0
# incidentType      0
# designatedArea    0
# disaster_area     0
# dtype: int64

# %%
duplicates = filtered_df[filtered_df.duplicated()]
print(duplicates)
# Out:
#        disasterNumber state  year incidentType  \
# 5235             4529    NM  2020   Biological
# 5256             4529    NM  2020   Biological
# 5262             4529    NM  2020   Biological
# 5264             4529    NM  2020   Biological
# 5404             4527    SD  2020   Biological
# 5433             4527    SD  2020   Biological
# 5450             4527    SD  2020   Biological
# 5453             4527    SD  2020   Biological
# 5457             4527    SD  2020   Biological
# 5459             4527    SD  2020   Biological
# 5464             4527    SD  2020   Biological
# 5468             4527    SD  2020   Biological
# 5471             4527    SD  2020   Biological
# 5484             4527    SD  2020   Biological
# 5488             4527    SD  2020   Biological
# 5507             4527    SD  2020   Biological
# 5512             4527    SD  2020   Biological
# 5857             4522    ME  2020   Biological
# 5868             4522    ME  2020   Biological
# 6077             4522    ME  2020   Biological
# 6131             4522    ME  2020   Biological
# 6135             4522    ME  2020   Biological
# 18181            3559    NM  2020   Biological
# 21206            3460    NM  2020   Biological
# 21227            3460    NM  2020   Biological
# 21233            3460    NM  2020   Biological
# 21235            3460    NM  2020   Biological
# 22443            3444    ME  2020   Biological
#
#                                   designatedArea  \
# 5235           Jemez Pueblo (Indian Reservation)
# 5256   Santo Domingo Pueblo (Indian Reservation)
# 5262             Zia Pueblo (Indian Reservation)
# 5264            Zuni Pueblo (Indian Reservation)
# 5404                       Lincoln (Township of)
# 5433                      Fairview (Township of)
# 5450                          Eden (Township of)
# 5453                       Lincoln (Township of)
# 5457                         Union (Township of)
# 5459                    Washington (Township of)
# 5464                        Banner (Township of)
# 5468                       Lincoln (Township of)
# 5471                         Union (Township of)
# 5484                       Liberty (Township of)
# 5488                       Lincoln (Township of)
# 5507                      Fairview (Township of)
# 5512                       Lincoln (Township of)
# 5857                       Perkins (Township of)
# 5868                    Washington (Township of)
# 6077                       Perkins (Township of)
# 6131                   Soldiertown (Township of)
# 6135                     Thorndike (Township of)
# 18181  Santo Domingo Pueblo (Indian Reservation)
# 21206          Jemez Pueblo (Indian Reservation)
# 21227  Santo Domingo Pueblo (Indian Reservation)
# 21233            Zia Pueblo (Indian Reservation)
# 21235           Zuni Pueblo (Indian Reservation)
# 22443                   Washington (Township of)
#
#                                      disaster_area
# 5235           Jemez Pueblo Indian Reservation, NM
# 5256   Santo Domingo Pueblo Indian Reservation, NM
# 5262             Zia Pueblo Indian Reservation, NM
# 5264            Zuni Pueblo Indian Reservation, NM
# 5404                       Lincoln Township of, SD
# 5433                      Fairview Township of, SD
# 5450                          Eden Township of, SD
# 5453                       Lincoln Township of, SD
# 5457                         Union Township of, SD
# 5459                    Washington Township of, SD
# 5464                        Banner Township of, SD
# 5468                       Lincoln Township of, SD
# 5471                         Union Township of, SD
# 5484                       Liberty Township of, SD
# 5488                       Lincoln Township of, SD
# 5507                      Fairview Township of, SD
# 5512                       Lincoln Township of, SD
# 5857                       Perkins Township of, ME
# 5868                    Washington Township of, ME
# 6077                       Perkins Township of, ME
# 6131                   Soldiertown Township of, ME
# 6135                     Thorndike Township of, ME
# 18181  Santo Domingo Pueblo Indian Reservation, NM
# 21206          Jemez Pueblo Indian Reservation, NM
# 21227  Santo Domingo Pueblo Indian Reservation, NM
# 21233            Zia Pueblo Indian Reservation, NM
# 21235           Zuni Pueblo Indian Reservation, NM
# 22443                   Washington Township of, ME

# %%
filtered_df = filtered_df.drop_duplicates()
filtered_df
# Out:
#        disasterNumber state  year  incidentType       designatedArea  \
# 0                5530    NV  2024          Fire      Washoe (County)
# 1                5529    OR  2024          Fire  Washington (County)
# 2                5528    OR  2024          Fire   Jefferson (County)
# 3                5527    OR  2024          Fire   Deschutes (County)
# 4                5526    CO  2024          Fire   Jefferson (County)
# ...               ...   ...   ...           ...                  ...
# 51574            1305    NH  2000     Hurricane     Belknap (County)
# 51575            1305    NH  2000     Hurricane    Cheshire (County)
# 51576            1305    NH  2000     Hurricane     Grafton (County)
# 51577            1304    AZ  2000  Severe Storm     Cochise (County)
# 51578            1304    AZ  2000  Severe Storm    Maricopa (County)
#
#                disaster_area
# 0          Washoe County, NV
# 1      Washington County, OR
# 2       Jefferson County, OR
# 3       Deschutes County, OR
# 4       Jefferson County, CO
# ...                      ...
# 51574     Belknap County, NH
# 51575    Cheshire County, NH
# 51576     Grafton County, NH
# 51577     Cochise County, AZ
# 51578    Maricopa County, AZ
#
# [47776 rows x 6 columns]

# %%
filtered_df['disasterNumber'].nunique()
# Out:
# 3282

# %%
import requests
from geopy.distance import geodesic
import pandas as pd
import time

# Replace with your filtered DataFrame
filtered_df = filtered_df.copy()  # Ensure filtered_df is defined elsewhere

# Store Google Maps API Key
api_key = "your-api-key-here"

# Function to get coordinates from Google Maps Geocoding API
def get_coordinates(address, api_key):
    try:
        url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={api_key}"
        response = requests.get(url, timeout=10)  # Add timeout
        data = response.json()
        if data['status'] == 'OK':
            lat = data['results'][0]['geometry']['location']['lat']
            lng = data['results'][0]['geometry']['location']['lng']
            return lat, lng
        print(f"Geocode API error for address {address}: {data.get('error_message', 'No error message')}")
    except Exception as e:
        print(f"Exception occurred while fetching coordinates for address {address}: {e}")
    return None, None

# Function to get distance and travel time from Google Maps Directions API
def get_distance_time(origin, destination, api_key):
    try:
        url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&key={api_key}"
        response = requests.get(url, timeout=10)  # Add timeout
        data = response.json()
        if data['status'] == 'OK':
            distance = data['routes'][0]['legs'][0]['distance']['value'] / 1000  # Convert to km
            duration = data['routes'][0]['legs'][0]['duration']['value'] / 60  # Convert to minutes
            return distance, duration
        print(f"Directions API error for origin {origin} and destination {destination}: {data.get('error_message', 'No error message')}")
    except Exception as e:
        print(f"Exception occurred while fetching distance and time for origin {origin} and destination {destination}: {e}")
    return None, None

#EOC names and addresses

eoc_addresses = {
    # California
    "Los Angeles Hub, CA": "500 E. Temple St., Los Angeles, CA 90012", 
    "San Francisco Hub, CA": "698 2nd St., San Francisco, CA 94107", 
    "Sacramento Hub, CA": "3650 Schriever Ave., Mather, CA 95655", 
    "San Diego Hub, CA": "5555 Overland Ave., San Diego, CA 92123", 
    "Fresno Hub, CA": "1221 Fulton Mall, Fresno, CA 93721", 
    "Oakland Hub, CA": "150 Frank H. Ogawa Plaza, Oakland, CA 94612", 
    "Riverside Hub, CA": "4080 Lemon St., Riverside, CA 92501", 
    "Long Beach Hub, CA": "2950 Redondo Ave., Long Beach, CA 90806",

    # Texas
    "Austin Hub, TX": "1033 La Posada Dr., Austin, TX 78752", 
    "Dallas Hub, TX": "1500 Marilla St., Dallas, TX 75201", 
    "Houston Hub, TX": "1001 Fannin St., Houston, TX 77002", 
    "San Antonio Hub, TX": "1619 San Pedro Ave., San Antonio, TX 78212", 

    # Florida
    "Tallahassee Hub, FL": "2555 Shumard Oak Blvd., Tallahassee, FL 32399", 
    "Miami Hub, FL": "4000 W Flagler St., Miami, FL 33134", 
    "Orlando Hub, FL": "400 W Robinson St., Orlando, FL 32801", 

    # New York
    "Albany Hub, NY": "1220 Washington Ave., Albany, NY 12226", 
    "New York City Hub, NY": "9 Metrotech Center, Brooklyn, NY 11201", 

    # Illinois
    "Springfield Hub, IL": "2200 S Dirksen Pkwy, Springfield, IL 62703", 
    "Chicago Hub, IL": "1300 W 22nd St., Oak Brook, IL 60523",

    # Pennsylvania
    "Harrisburg Hub, PA": "101 S. 7th St., Harrisburg, PA 17104", 
    "Philadelphia Hub, PA": "3600 Roosevelt Blvd, Philadelphia, PA 19149",

    # Georgia
    "Atlanta Hub, GA": "935 E Confederate Ave, Atlanta, GA 30316", 

    # Ohio
    "Columbus Hub, OH": "2855 W Dublin Granville Rd., Columbus, OH 43235",

    # Washington
    "Olympia Hub, WA": "106 11th Ave SW, Olympia, WA 98504", 
    "Seattle Hub, WA": "711 2nd Ave., Seattle, WA 98104",

    # Michigan
    "Lansing Hub, MI": "4000 Collins Rd, Lansing, MI 48910", 

    # Virginia
    "Richmond Hub, VA": "10501 Trade Ct, Richmond, VA 23236",

    # Arizona
    "Phoenix Hub, AZ": "5636 E McKinley St., Phoenix, AZ 85008",

    # North Carolina
    "Raleigh Hub, NC": "1636 Gold Star Dr., Raleigh, NC 27607",

    # Minnesota
    "St. Paul Hub, MN": "444 Cedar St, St. Paul, MN 55101",

    # Maine
    "Augusta Hub, ME": "45 Commerce Dr, Augusta, ME 04330",

    # Colorado
    "Denver Hub, CO": "745 W Colfax Ave, Denver, CO 80204",

    # Nevada
    "Carson City Hub, NV": "2478 Fairview Dr., Carson City, NV 89701",

    # Louisiana
    "Baton Rouge Hub, LA": "3500 N. Acadian Thruway, Baton Rouge, LA 70805",

    # Tennessee
    "Nashville Hub, TN": "600 W. Main St., Nashville, TN 37208",

    # Maryland
    "Baltimore Hub, MD": "2930 4th St., Baltimore, MD 21225",

    # Arkansas
    "Little Rock Hub, AR": "10800 Financial Center Parkway, Little Rock, AR 72211",

    # Oklahoma
    "Oklahoma City Hub, OK": "1700 SW 7th St., Oklahoma City, OK 73108",

    # Wisconsin
    "Madison Hub, WI": "2400 Wright St., Madison, WI 53704",

    # South Carolina
    "Columbia Hub, SC": "2920 Broad River Rd., Columbia, SC 29210",

    # Kansas
    "Topeka Hub, KS": "2800 SW Topeka Blvd, Topeka, KS 66611",

    # Alabama
    "Montgomery Hub, AL": "5095 Rev. Abraham Woods Jr. Blvd, Montgomery, AL 36108",

    # Connecticut
    "Hartford Hub, CT": "25 Sigourney St., Hartford, CT 06105",

    # New Jersey
    "Trenton Hub, NJ": "4001 S. Broad St., Trenton, NJ 08648",

    # South Dakota
    "Pierre Hub, SD": "500 E. Capitol Ave., Pierre, SD 57501",

    # New Mexico
    "Santa Fe Hub, NM": "6200 Brown Rd., Santa Fe, NM 87507",

    # Kentucky
    "Frankfort Hub, KY": "1311 US Hwy 127 S, Frankfort, KY 40601",

    # Nebraska
    "Lincoln Hub, NE": "1300 15th St, Lincoln, NE 68508",

    # Montana
    "Helena Hub, MT": "1201 E 6th Ave, Helena, MT 59620",

    # Wyoming
    "Cheyenne Hub, WY": "5500 Bishop Blvd., Cheyenne, WY 82006",

    # Idaho
    "Boise Hub, ID": "4040 W. Guard St., Boise, ID 83705",

    # Mississippi
    "Jackson Hub, MS": "570 E. Woodrow Wilson Dr., Jackson, MS 39216",

    # Rhode Island
    "Providence Hub, RI": "1600 Division St., Cranston, RI 02920",

    # Delaware
    "Dover Hub, DE": "165 Brick Store Landing Rd., Dover, DE 19901",

    # Vermont
    "Montpelier Hub, VT": "10 Baldwin St., Montpelier, VT 05602",

    # Hawaii
    "Honolulu Hub, HI": "925 Dillingham Blvd, Honolulu, HI 96817",

    # Alaska
    "Anchorage Hub, AK": "550 W 7th Ave, Anchorage, AK 99501",

    # Indiana
    "Indianapolis Hub, IN": "302 W Washington St., Indianapolis, IN 46204",

    # Missouri
    "Jefferson City Hub, MO": "2302 E McCarty St, Jefferson City, MO 65101",

    # Utah
    "Salt Lake City Hub, UT": "1600 W North Temple, Salt Lake City, UT 84116",

    # North Dakota
    "Bismarck Hub, ND": "4201 Coleman St, Bismarck, ND 58503",

    # West Virginia
    "Charleston Hub, WV": "1900 Kanawha Blvd. E, Charleston, WV 25305",

}


# Pre-fetch coordinates for EOCs
eoc_coordinates = {}
for hub, address in eoc_addresses.items():
    coords = get_coordinates(address, api_key)
    if coords != (None, None):
        eoc_coordinates[hub] = coords
    else:
        print(f"Skipping {hub} due to missing coordinates.")

# Add new columns to the DataFrame
filtered_df['EOC'] = None
filtered_df['Disaster Lat'] = None
filtered_df['Disaster Lng'] = None
filtered_df['EOC Lat'] = None
filtered_df['EOC Lng'] = None
filtered_df['Distance (km)'] = None
filtered_df['Duration (minutes)'] = None

# Calculate closest EOC for each disaster area
for idx, row in filtered_df.iterrows():
    disaster_area = row['disaster_area']
    print(f"Processing row {idx}: {disaster_area}")
    
    disaster_coords = get_coordinates(disaster_area, api_key)
    if disaster_coords != (None, None):
        closest_eoc = None
        min_distance = float('inf')
        for eoc, eoc_coords in eoc_coordinates.items():
            try:
                distance = geodesic(disaster_coords, eoc_coords).kilometers
                if distance < min_distance:
                    min_distance = distance
                    closest_eoc = eoc
            except Exception as e:
                print(f"Error calculating geodesic distance for {disaster_area} and {eoc}: {e}")
        
        if closest_eoc:
            travel_distance, travel_duration = get_distance_time(
                origin=f"{eoc_coordinates[closest_eoc][0]},{eoc_coordinates[closest_eoc][1]}",
                destination=f"{disaster_coords[0]},{disaster_coords[1]}",
                api_key=api_key
            )
            filtered_df.at[idx, 'EOC'] = closest_eoc
            filtered_df.at[idx, 'Disaster Lat'] = disaster_coords[0]
            filtered_df.at[idx, 'Disaster Lng'] = disaster_coords[1]
            filtered_df.at[idx, 'EOC Lat'] = eoc_coordinates[closest_eoc][0]
            filtered_df.at[idx, 'EOC Lng'] = eoc_coordinates[closest_eoc][1]
            filtered_df.at[idx, 'Distance (km)'] = travel_distance
            filtered_df.at[idx, 'Duration (minutes)'] = travel_duration
        else:
            print(f"No valid EOC found for {disaster_area}.")
    else:
        print(f"Skipping disaster area {disaster_area} due to missing coordinates.")

    # Introduce a small delay to avoid exceeding API rate limits
    time.sleep(0.2)

print(filtered_df.head())
# Out:
# Processing row 0: Washoe County, NV
# Processing row 1: Washington County, OR
# Processing row 2: Jefferson County, OR
# Processing row 3: Deschutes County, OR
# Processing row 4: Jefferson County, CO
# Processing row 5: Boulder County, CO
# Processing row 6: Larimer County, CO
# Processing row 7: Larimer County, CO
# Processing row 8: Platte County, WY
# Processing row 9: Kern County, CA
# Processing row 10: Yakima County, WA
# Processing row 11: Nez Perce Indian Reservation, ID
# Processing row 12: Latah County, ID
# Processing row 13: Nez Perce County, ID
# Processing row 14: Butte County, CA
# Processing row 15: Tehama County, CA
# Processing row 16: Colville Indian Reservation, WA
# Processing row 17: Ferry County, WA
# Processing row 18: Okanogan County, WA
# Processing row 19: Yakama Reservation, WA
# Processing row 20: Yakima County, WA
# Processing row 21: Baker County, OR
# Processing row 22: Malheur County, OR
# Processing row 23: Riverside County, CA
# Processing row 24: Grant County, OR
# Processing row 25: Morrow County, OR
# Processing row 26: Umatilla County, OR
# Processing row 27: Grant County, OR
# Processing row 28: Grant County, OR
# Processing row 29: Harney County, OR
# Processing row 30: Gilliam County, OR
# Processing row 31: Morrow County, OR
# Processing row 32: Wheeler County, OR
# Processing row 33: Latah County, ID
# Processing row 34: Nez Perce County, ID
# Processing row 35: Douglas County, NV
# Processing row 36: San Carlos Indian Reservation, AZ
# Processing row 37: Broadwater County, MT
# Processing row 38: Lewis and Clark County, MT
# Processing row 39: Wasco County, OR
# Processing row 40: Pinal County, AZ
# Processing row 41: Piute County, UT
# Processing row 42: Mariposa County, CA
# Processing row 43: Butte County, CA
# Processing row 44: Maricopa County, AZ
# Processing row 45: Deschutes County, OR
# Processing row 46: Yakama Reservation, WA
# Processing row 47: Yakima County, WA
# Processing row 48: Mescalero Tribe, NM
# Processing row 49: Lincoln County, NM
# Processing row 50: Otero County, NM
# Processing row 51: Mescalero Tribe, NM
# Processing row 52: Lincoln County, NM
# Processing row 53: Otero County, NM
# Processing row 54: Maricopa County, AZ
# Processing row 55: Washoe County, NV
# Processing row 56: Washoe County, NV
# Processing row 57: Pinal County, AZ
# Processing row 58: Lincoln County, NM
# Processing row 59: Woodward County, OK
# Processing row 60: Laramie County, WY
# Processing row 61: Ellis County, OK
# Processing row 62: Hemphill County, TX
# Processing row 63: Hutchinson County, TX
# Processing row 64: Roberts County, TX
# Processing row 65: Moore County, TX
# Processing row 66: Rapides Parish, LA
# Processing row 67: Vernon Parish, LA
# Processing row 68: Vernon Parish, LA
# Processing row 69: Vernon Parish, LA
# Processing row 70: Marion County, OR
# Processing row 71: Beauregard Parish, LA
# Processing row 72: Spokane County, WA
# Processing row 73: Sanders County, MT
# Processing row 74: Spokane County, WA
# Processing row 75: Hawaii County, HI
# Directions API error for origin 21.3199566,-157.8706382 and destination 19.5429151,-155.6658568: No error message
# Processing row 76: Maui County, HI
# Directions API error for origin 21.3199566,-157.8706382 and destination 20.7983626,-156.3319253: No error message
# Processing row 77: Maui County, HI
# Directions API error for origin 21.3199566,-157.8706382 and destination 20.7983626,-156.3319253: No error message
# Processing row 78: Maui County, HI
# Directions API error for origin 21.3199566,-157.8706382 and destination 20.7983626,-156.3319253: No error message
# Processing row 79: Hawaii County, HI
# Directions API error for origin 21.3199566,-157.8706382 and destination 19.5429151,-155.6658568: No error message
# Processing row 80: Fairbanks North Star Borough, AK
# Processing row 81: Okanogan County, WA
# Processing row 82: Klamath County, OR
# Processing row 83: Klickitat County, WA
# Processing row 84: Grant County, WA
# Processing row 85: Mason County, WA
# Processing row 86: Skamania County, WA
# Processing row 87: Maricopa County, AZ
# Processing row 88: Mora County, NM
# Processing row 89: San Miguel County, NM
# Processing row 90: Washington Countyin PMSA 5520,6480, RI
# Processing row 91: Washington County, KS
# Processing row 92: Cass County, NE
# Processing row 93: Torrance County, NM
# Processing row 94: Washington County, OK
# Processing row 95: Oklahoma County, OK
# Processing row 96: Logan County, OK
# Processing row 97: Lane County, OR
# Processing row 98: Clark County, WA
# Processing row 99: Skamania County, WA
# Processing row 100: King County, WA
# Processing row 101: Snohomish County, WA
# Processing row 102: Clackamas County, OR
# Processing row 103: El Dorado County, CA
# Processing row 104: Placer County, CA
# Processing row 105: Blaine County, ID
# Processing row 106: Riverside County, CA
# Processing row 107: Siskiyou County, CA
# Processing row 108: Adams County, ID
# Processing row 109: Gem County, ID
# Processing row 110: Valley County, ID
# Processing row 111: Washoe County, NV
# Processing row 112: Adams County, WA
# Processing row 113: Wasco County, OR
# Processing row 114: Mariposa County, CA
# Processing row 115: Hood County, TX
# Processing row 116: Somervell County, TX
# Processing row 117: Bosque County, TX
# Processing row 118: Denali Borough, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 63.82571729999999,-149.7317834: No error message
# Processing row 119: Yukon-Koyukuk Census Area, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 65.8443667,-153.4302993: No error message
# Processing row 120: Coconino County, AZ
# Processing row 121: Taylor County, TX
# Processing row 122: Orange County, CA
# Processing row 123: San Miguel County, NM
# Processing row 124: Colfax County, NM
# Processing row 125: Frontier County, NE
# Processing row 126: Furnas County, NE
# Processing row 127: Red Willow County, NE
# Processing row 128: Yavapai County, AZ
# Processing row 129: Coconino County, AZ
# Processing row 130: Lincoln County, NM
# Processing row 131: Lincoln County, NM
# Processing row 132: San Miguel County, NM
# Processing row 133: Valencia County, NM
# Processing row 134: Hood County, TX
# Processing row 135: Eastland County, TX
# Processing row 136: Eastland County, TX
# Processing row 137: Bay County, FL
# Processing row 138: Calhoun County, FL
# Processing row 139: Harvey County, KS
# Processing row 140: Reno County, KS
# Processing row 141: Bay County, FL
# Processing row 142: Boulder County, CO
# Processing row 143: Carson County, TX
# Processing row 144: Texas County, OK
# Processing row 145: Wichita County, TX
# Processing row 146: Santa Barbara County, CA
# Processing row 147: Pennington County, SD
# Processing row 148: Shasta County, CA
# Processing row 149: Kern County, CA
# Processing row 150: Yakima County, WA
# Processing row 151: Chelan County, WA
# Processing row 152: El Dorado County, CA
# Processing row 153: Trinity County, CA
# Processing row 154: Stevens County, WA
# Processing row 155: Okanogan County, WA
# Processing row 156: Lake County, OR
# Processing row 157: Salt Lake County, UT
# Processing row 158: Summit County, UT
# Processing row 159: Nez Perce Indian Reservation, ID
# Processing row 160: Nez Perce County, ID
# Processing row 161: Rosebud County, MT
# Processing row 162: Placer County, CA
# Processing row 163: Hawaii County, HI
# Directions API error for origin 21.3199566,-157.8706382 and destination 19.5429151,-155.6658568: No error message
# Processing row 164: Crow Indian Reservation, MT
# Processing row 165: Big Horn County, MT
# Processing row 166: Douglas County, NV
# Processing row 167: Okanogan County, WA
# Processing row 168: Lassen County, CA
# Processing row 169: Plumas County, CA
# Processing row 170: Yellowstone County, MT
# Processing row 171: Chelan County, WA
# Processing row 172: Colville Indian Reservation, WA
# Processing row 173: Klamath County, OR
# Processing row 174: Lake County, OR
# Processing row 175: Spokane County, WA
# Processing row 176: Deschutes County, OR
# Processing row 177: Siskiyou County, CA
# Processing row 178: Carbon County, MT
# Processing row 179: San Juan County, UT
# Processing row 180: Douglas County, NV
# Processing row 181: Gila County, AZ
# Processing row 182: Pinal County, AZ
# Processing row 183: Garfield County, UT
# Processing row 184: Yavapai County, AZ
# Processing row 185: Lincoln County, NM
# Processing row 186: Pinal County, AZ
# Processing row 187: Pennington County, SD
# Processing row 188: Orange County, CA
# Processing row 189: Washoe County, NV
# Processing row 190: Orange County, CA
# Processing row 191: Riverside County, CA
# Processing row 192: San Bernardino County, CA
# Directions API error for origin 33.9778573,-117.3733941 and destination 34.9592083,-116.419389: No error message
# Processing row 193: Orange County, CA
# Processing row 194: Boulder County, CO
# Processing row 195: Grand County, CO
# Processing row 196: Shasta County, CA
# Processing row 197: Napa County, CA
# Processing row 198: Sonoma County, CA
# Processing row 199: Albany County, WY
# Processing row 200: Carbon County, WY
# Processing row 201: Los Angeles County, CA
# Processing row 202: Tulare County, CA
# Processing row 203: Lake County, OR
# Processing row 204: Washington County, OR
# Processing row 205: Yamhill County, OR
# Processing row 206: Clackamas County, OR
# Processing row 207: Josephine County, OR
# Processing row 208: Tillamook County, OR
# Processing row 209: Jackson County, OR
# Processing row 210: Clackamas County, OR
# Processing row 211: Douglas County, OR
# Processing row 212: Jackson County, OR
# Processing row 213: Butte County, CA
# Processing row 214: Plumas County, CA
# Processing row 215: Yuba County, CA
# Processing row 216: Lincoln County, OR
# Processing row 217: Siskiyou County, CA
# Processing row 218: Pierce County, WA
# Processing row 219: Thurston County, WA
# Processing row 220: Washington County, OR
# Processing row 221: Lane County, OR
# Processing row 222: Warm Springs Indian Reservation, OR
# Processing row 223: Clackamas County, OR
# Processing row 224: Jefferson County, OR
# Processing row 225: Linn County, OR
# Processing row 226: Marion County, OR
# Processing row 227: Spokane County, WA
# Processing row 228: Whitman County, WA
# Processing row 229: Klamath County, OR
# Processing row 230: Utah County, UT
# Processing row 231: Chelan County, WA
# Processing row 232: Colville Indian Reservation, WA
# Processing row 233: Douglas County, WA
# Processing row 234: Okanogan County, WA
# Processing row 235: San Bernardino County, CA
# Directions API error for origin 33.9778573,-117.3733941 and destination 34.9592083,-116.419389: No error message
# Processing row 236: Larimer County, CO
# Processing row 237: Fresno County, CA
# Processing row 238: Madera County, CA
# Processing row 239: Carbon County, WY
# Processing row 240: Gallatin County, MT
# Processing row 241: Custer County, MT
# Processing row 242: Powder River County, MT
# Processing row 243: Rosebud County, MT
# Processing row 244: Musselshell County, MT
# Processing row 245: Yellowstone County, MT
# Processing row 246: Garfield County, MT
# Processing row 247: Yakima County, WA
# Processing row 248: Wasco County, OR
# Processing row 249: San Carlos Indian Reservation, AZ
# Processing row 250: Gila County, AZ
# Processing row 251: Lassen County, CA
# Processing row 252: Santa Clara County, CA
# Processing row 253: Stanislaus County, CA
# Processing row 254: Okanogan County, WA
# Processing row 255: San Mateo County, CA
# Processing row 256: Santa Cruz County, CA
# Processing row 257: Garfield County, CO
# Processing row 258: Mesa County, CO
# Processing row 259: Eagle County, CO
# Processing row 260: Garfield County, CO
# Processing row 261: Monterey County, CA
# Processing row 262: Nevada County, CA
# Processing row 263: Lake County, CA
# Processing row 264: Napa County, CA
# Processing row 265: Solano County, CA
# Processing row 266: Sonoma County, CA
# Processing row 267: Yolo County, CA
# Processing row 268: Yakama Reservation, WA
# Processing row 269: Yakima County, WA
# Processing row 270: Monterey County, CA
# Processing row 271: Washoe County, NV
# Processing row 272: Wasco County, OR
# Processing row 273: Washoe County, NV
# Processing row 274: Morongo Indian Reservation, CA
# Processing row 275: Riverside County, CA
# Processing row 276: San Bernardino County, CA
# Directions API error for origin 33.9778573,-117.3733941 and destination 34.9592083,-116.419389: No error message
# Processing row 277: Stillwater County, MT
# Processing row 278: Yellowstone County, MT
# Processing row 279: Okanogan County, WA
# Processing row 280: Washoe County, NV
# Processing row 281: Washington County, UT
# Processing row 282: Douglas County, WA
# Processing row 283: Douglas County, NV
# Processing row 284: Utah County, UT
# Processing row 285: Millard County, UT
# Processing row 286: Washoe County, NV
# Processing row 287: Maricopa County, AZ
# Processing row 288: Maricopa County, AZ
# Processing row 289: Gila County, AZ
# Processing row 290: Maricopa County, AZ
# Processing row 291: Pima County, AZ
# Processing row 292: Maricopa County, AZ
# Processing row 293: Maricopa County, AZ
# Processing row 294: Collier County, FL
# Processing row 295: Walton County, FL
# Processing row 296: Santa Rosa County, FL
# Processing row 297: Beaver County, OK
# Processing row 298: Ellis County, OK
# Processing row 299: Woodward County, OK
# Processing row 300: Santa Barbara County, CA
# Processing row 301: Ventura County, CA
# Processing row 302: San Bernardino County, CA
# Directions API error for origin 33.9778573,-117.3733941 and destination 34.9592083,-116.419389: No error message
# Processing row 303: Riverside County, CA
# Processing row 304: Riverside County, CA
# Processing row 305: Ventura County, CA
# Processing row 306: Los Angeles County, CA
# Processing row 307: Los Angeles County, CA
# Processing row 308: Sonoma County, CA
# Processing row 309: Maui County, HI
# Directions API error for origin 21.3199566,-157.8706382 and destination 20.7983626,-156.3319253: No error message
# Processing row 310: Los Angeles County, CA
# Processing row 311: Ventura County, CA
# Processing row 312: Davis County, UT
# Directions API error for origin 40.7722698,-111.9376221 and destination 40.9628845,-112.0953297: No error message
# Processing row 313: Washoe County, NV
# Processing row 314: Matanuska-Susitna Borough, AK
# Processing row 315: Douglas County, NV
# Processing row 316: Hardeman County, TX
# Processing row 317: Matanuska-Susitna Borough, AK
# Processing row 318: Lewis and Clark County, MT
# Processing row 319: Douglas County, OR
# Processing row 320: Coconino County, AZ
# Processing row 321: Washoe County, NV
# Processing row 322: Fairbanks North Star Borough, AK
# Processing row 323: Valencia County, NM
# Processing row 324: Los Angeles County, CA
# Processing row 325: Ventura County, CA
# Processing row 326: Ventura County, CA
# Processing row 327: Butte County, CA
# Processing row 328: Utah County, UT
# Processing row 329: Sublette County, WY
# Processing row 330: Ferry County, WA
# Processing row 331: Fall River County, SD
# Processing row 332: Douglas County, WA
# Processing row 333: Grant County, WA
# Processing row 334: Dubuque County, IA
# Processing row 335: Chelan County, WA
# Processing row 336: Yakama Reservation, WA
# Processing row 337: Yakima County, WA
# Processing row 338: Riverside County, CA
# Processing row 339: Sanpete County, UT
# Processing row 340: Lincoln County, WA
# Processing row 341: Burnet County, TX
# Processing row 342: Clark County, ID
# Processing row 343: Hopland Rancheria Indian Reservation, CA
# Processing row 344: Lake County, CA
# Processing row 345: Mendocino County, CA
# Processing row 346: Douglas County, WA
# Processing row 347: Jackson County, IA
# Processing row 348: Riverside County, CA
# Processing row 349: Shasta County, CA
# Processing row 350: Trinity County, CA
# Processing row 351: Brown County, TX
# Processing row 352: Grant County, WA
# Processing row 353: Spokane County, WA
# Processing row 354: Kittitas County, WA
# Processing row 355: Santa Barbara County, CA
# Processing row 356: San Diego County, CA
# Processing row 357: Siskiyou County, CA
# Processing row 358: Eagle County, CO
# Processing row 359: Duchesne County, UT
# Processing row 360: Wasatch County, UT
# Processing row 361: Teller County, CO
# Processing row 362: Costilla County, CO
# Processing row 363: Scott County, IA
# Processing row 364: Huerfano County, CO
# Processing row 365: Shasta County, CA
# Processing row 366: Lake County, CA
# Processing row 367: Jefferson County, OR
# Processing row 368: Lyon County, NV
# Processing row 369: Albany County, WY
# Processing row 370: Otero County, NM
# Processing row 371: Colfax County, NM
# Processing row 372: Yavapai County, AZ
# Processing row 373: Jeff Davis County, TX
# Processing row 374: Coconino County, AZ
# Processing row 375: Gray County, TX
# Processing row 376: Jones County, TX
# Processing row 377: Hutchinson County, TX
# Processing row 378: Dewey County, OK
# Processing row 379: Woodward County, OK
# Processing row 380: Pottawatomie County, OK
# Processing row 381: Custer County, SD
# Processing row 382: San Diego County, CA
# Processing row 383: Los Angeles County, CA
# Processing row 384: Los Angeles County, CA
# Processing row 385: Los Angeles County, CA
# Processing row 386: Santa Barbara County, CA
# Processing row 387: Ventura County, CA
# Processing row 388: Orange County, CA
# Processing row 389: Riverside County, CA
# Processing row 390: Napa County, CA
# Processing row 391: Sonoma County, CA
# Processing row 392: Lake County, CA
# Processing row 393: Sonoma County, CA
# Processing row 394: Mendocino County, CA
# Processing row 395: Butte County, CA
# Processing row 396: Nevada County, CA
# Processing row 397: Butte County, CA
# Processing row 398: Yuba County, CA
# Processing row 399: Napa County, CA
# Processing row 400: Sonoma County, CA
# Processing row 401: Napa County, CA
# Processing row 402: Solano County, CA
# Processing row 403: Orange County, CA
# Processing row 404: Riverside County, CA
# Processing row 405: Blackfeet Indian Reservation, MT
# Processing row 406: Pondera County, MT
# Processing row 407: Teton County, MT
# Processing row 408: Lincoln County, MT
# Processing row 409: Sanders County, MT
# Processing row 410: Sanders County, MT
# Processing row 411: Lincoln County, MT
# Processing row 412: Lewis and Clark County, MT
# Processing row 413: Missoula County, MT
# Processing row 414: Powell County, MT
# Processing row 415: Davis County, UT
# Directions API error for origin 40.7722698,-111.9376221 and destination 40.9628845,-112.0953297: No error message
# Processing row 416: Weber County, UT
# Processing row 417: Tulare County, CA
# Processing row 418: Madera County, CA
# Processing row 419: Hood River County, OR
# Processing row 420: Multnomah County, OR
# Processing row 421: Madera County, CA
# Processing row 422: Mariposa County, CA
# Processing row 423: Los Angeles County, CA
# Processing row 424: Kittitas County, WA
# Processing row 425: Trinity County, CA
# Processing row 426: Curry County, OR
# Processing row 427: Missoula County, MT
# Processing row 428: Ravalli County, MT
# Processing row 429: Deschutes County, OR
# Processing row 430: Klamath County, OR
# Processing row 431: Garfield County, MT
# Processing row 432: Petroleum County, MT
# Processing row 433: Douglas County, NV
# Processing row 434: Mariposa County, CA
# Processing row 435: Elko County, NV
# Processing row 436: Washoe County, NV
# Processing row 437: Butte County, CA
# Processing row 438: Pinal County, AZ
# Processing row 439: Yakima County, WA
# Processing row 440: Yavapai County, AZ
# Processing row 441: Iron County, UT
# Processing row 442: Sandoval County, NM
# Processing row 443: Cochise County, AZ
# Processing row 444: Chelan County, WA
# Processing row 445: Charlton County, GA
# Processing row 446: Clinch County, GA
# Processing row 447: Ware County, GA
# Processing row 448: Polk County, FL
# Processing row 449: Lee County, FL
# Processing row 450: Collier County, FL
# Processing row 451: Beaver County, OK
# Processing row 452: Ellis County, OK
# Processing row 453: Harper County, OK
# Processing row 454: Woods County, OK
# Processing row 455: Woodward County, OK
# Processing row 456: Comanche County, KS
# Processing row 457: Rooks County, KS
# Processing row 458: Ness County, KS
# Processing row 459: Ford County, KS
# Processing row 460: Ellsworth County, KS
# Processing row 461: Lincoln County, KS
# Processing row 462: Russell County, KS
# Processing row 463: Clark County, KS
# Processing row 464: McPherson County, KS
# Processing row 465: Reno County, KS
# Processing row 466: Rice County, KS
# Processing row 467: Wagoner County, OK
# Processing row 468: Cleveland County, OK
# Processing row 469: Sevier County, TN
# Processing row 470: Harlan County, KY
# Processing row 471: Knox County, KY
# Processing row 472: Letcher County, KY
# Processing row 473: Pike County, KY
# Processing row 474: Blount County, TN
# Processing row 475: Burke County, NC
# Processing row 476: Dade County, GA
# Processing row 477: Buncombe County, NC
# Processing row 478: Henderson County, NC
# Processing row 479: Rutherford County, NC
# Processing row 480: Bledsoe County, TN
# Processing row 481: Hamilton County, TN
# Processing row 482: Sequatchie County, TN
# Processing row 483: Hamilton County, TN
# Processing row 484: Breathitt County, KY
# Processing row 485: Custer County, CO
# Processing row 486: Pueblo County, CO
# Processing row 487: Washoe County, NV
# Processing row 488: Pueblo County, CO
# Processing row 489: Douglas County, NV
# Processing row 490: Josephine County, OR
# Processing row 491: Chelan County, WA
# Processing row 492: Bonneville County, ID
# Processing row 493: Kern County, CA
# Processing row 494: Tulare County, CA
# Processing row 495: Spokane County, WA
# Processing row 496: Spokane County, WA
# Processing row 497: San Bernardino County, CA
# Directions API error for origin 33.9778573,-117.3733941 and destination 34.9592083,-116.419389: No error message
# Processing row 498: San Luis Obispo County, CA
# Processing row 499: Lake County, CA
# Processing row 500: San Bernardino County, CA
# Directions API error for origin 33.9778573,-117.3733941 and destination 34.9592083,-116.419389: No error message
# Processing row 501: Ravalli County, MT
# Processing row 502: Benton County, WA
# Processing row 503: Washoe County, NV
# Processing row 504: Fresno County, CA
# Processing row 505: Uinta County, WY
# Processing row 506: Washoe County, NV
# Processing row 507: Monterey County, CA
# Processing row 508: Fremont County, WY
# Processing row 509: Los Angeles County, CA
# Processing row 510: Otero County, NM
# Processing row 511: Statewide, CO
# Geocode API error for address Statewide, CO: No error message
# Skipping disaster area Statewide, CO due to missing coordinates.
# Processing row 512: Los Angeles County, CA
# Processing row 513: Kern County, CA
# Processing row 514: Washington County, UT
# Processing row 515: Los Angeles County, CA
# Processing row 516: San Diego County, CA
# Processing row 517: Bernalillo County, NM
# Processing row 518: Torrance County, NM
# Processing row 519: Jefferson County, OR
# Processing row 520: Yavapai County, AZ
# Processing row 521: Los Angeles County, CA
# Processing row 522: Cheshire County, NH
# Processing row 523: Woodward County, OK
# Processing row 524: Wabaunsee County, KS
# Processing row 525: Barber County, KS
# Processing row 526: Comanche County, KS
# Processing row 527: Pawnee County, OK
# Processing row 528: Creek County, OK
# Processing row 529: Nowata County, OK
# Processing row 530: Washington County, OK
# Processing row 531: Bastrop County, TX
# Processing row 532: Natrona County, WY
# Processing row 533: Baker County, OR
# Processing row 534: Klickitat County, WA
# Processing row 535: Lake County, CA
# Processing row 536: Napa County, CA
# Processing row 537: Sonoma County, CA
# Processing row 538: Amador County, CA
# Processing row 539: Calaveras County, CA
# Processing row 540: Idaho County, ID
# Processing row 541: Skagit County, WA
# Processing row 542: Whatcom County, WA
# Processing row 543: Ferry County, WA
# Processing row 544: Stevens County, WA
# Processing row 545: Wallowa County, OR
# Processing row 546: Okanogan County, WA
# Processing row 547: Clearwater County, ID
# Processing row 548: Ferry County, WA
# Processing row 549: Okanogan County, WA
# Processing row 550: Stevens County, WA
# Processing row 551: Grant County, OR
# Processing row 552: Ferry County, WA
# Processing row 553: Chelan County, WA
# Processing row 554: Douglas County, WA
# Processing row 555: Okanogan County, WA
# Processing row 556: Idaho County, ID
# Processing row 557: Lewis County, ID
# Processing row 558: Okanogan County, WA
# Processing row 559: Baker County, OR
# Processing row 560: Josephine County, OR
# Processing row 561: Mohave County, AZ
# Processing row 562: Klickitat County, WA
# Processing row 563: Lake County, CA
# Processing row 564: Douglas County, OR
# Processing row 565: Napa County, CA
# Processing row 566: Solano County, CA
# Processing row 567: Yolo County, CA
# Processing row 568: Walla Walla County, WA
# Processing row 569: San Bernardino County, CA
# Directions API error for origin 33.9778573,-117.3733941 and destination 34.9592083,-116.419389: No error message
# Processing row 570: Bonner County, ID
# Processing row 571: Kootenai County, ID
# Processing row 572: Chelan County, WA
# Processing row 573: Pinal County, AZ
# Processing row 574: Kenai Peninsula Borough, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 60.0858486,-151.3822641: No error message
# Processing row 575: Matanuska-Susitna Borough, AK
# Processing row 576: Coconino County, AZ
# Processing row 577: Placer County, CA
# Processing row 578: El Dorado County, CA
# Processing row 579: Clackamas County, OR
# Processing row 580: Siskiyou County, CA
# Processing row 581: Madera County, CA
# Processing row 582: Mariposa County, CA
# Processing row 583: Trinity County, CA
# Processing row 584: Kern County, CA
# Processing row 585: Madera County, CA
# Processing row 586: Wasco County, OR
# Processing row 587: Chelan County, WA
# Processing row 588: Kittitas County, WA
# Processing row 589: Modoc County, CA
# Processing row 590: Lassen County, CA
# Processing row 591: Shasta County, CA
# Processing row 592: Siskiyou County, CA
# Processing row 593: Shasta County, CA
# Processing row 594: Jackson County, OR
# Processing row 595: Klamath County, OR
# Processing row 596: Tooele County, UT
# Processing row 597: Kittitas County, WA
# Processing row 598: Lincoln County, WA
# Processing row 599: Spokane County, WA
# Processing row 600: Okanogan County, WA
# Processing row 601: Chelan County, WA
# Processing row 602: Klamath County, OR
# Processing row 603: Chelan County, WA
# Processing row 604: Stevens County, WA
# Processing row 605: Napa County, CA
# Processing row 606: Deschutes County, OR
# Processing row 607: San Diego County, CA
# Processing row 608: San Diego County, CA
# Processing row 609: Hutchinson County, TX
# Processing row 610: Logan County, OK
# Processing row 611: Los Angeles County, CA
# Processing row 612: Shasta County, CA
# Processing row 613: Mariposa County, CA
# Processing row 614: Tuolumne County, CA
# Processing row 615: Chelan County, WA
# Processing row 616: Missoula County, MT
# Processing row 617: Hood River County, OR
# Processing row 618: Wasco County, OR
# Processing row 619: Blaine County, ID
# Processing row 620: Camas County, ID
# Processing row 621: Summit County, UT
# Processing row 622: Elmore County, ID
# Processing row 623: Chelan County, WA
# Processing row 624: Riverside County, CA
# Processing row 625: Riverside County, CA
# Processing row 626: Josephine County, OR
# Processing row 627: Chelan County, WA
# Processing row 628: Kittitas County, WA
# Processing row 629: Douglas County, OR
# Processing row 630: Josephine County, OR
# Processing row 631: Josephine County, OR
# Processing row 632: Mineral County, MT
# Processing row 633: Clark County, NV
# Processing row 634: Mohave County, AZ
# Processing row 635: Yavapai County, AZ
# Processing row 636: Mineral County, CO
# Processing row 637: Rio Grande County, CO
# Processing row 638: Huerfano County, CO
# Processing row 639: Yavapai County, AZ
# Processing row 640: Fremont County, CO
# Processing row 641: El Paso County, CO
# Processing row 642: San Miguel County, NM
# Processing row 643: Los Angeles County, CA
# Processing row 644: Ventura County, CA
# Processing row 645: Riverside County, CA
# Processing row 646: Custer County, CO
# Processing row 647: Pueblo County, CO
# Processing row 648: Campo Indian Reservation, CA
# Processing row 649: San Diego County, CA
# Processing row 650: Chelan County, WA
# Processing row 651: Kittitas County, WA
# Processing row 652: Boise County, ID
# Processing row 653: Chelan County, WA
# Processing row 654: Chelan County, WA
# Processing row 655: Ravalli County, MT
# Processing row 656: Chelan County, WA
# Processing row 657: Natrona County, WY
# Processing row 658: Douglas County, WA
# Processing row 659: Grant County, WA
# Processing row 660: Chelan County, WA
# Processing row 661: Klickitat County, WA
# Processing row 662: Oglala Lakota County, SD
# Processing row 663: Dawes County, NE
# Processing row 664: Sheridan County, NE
# Processing row 665: Sioux County, NE
# Processing row 666: Jefferson County, MT
# Processing row 667: Shasta County, CA
# Processing row 668: Tehama County, CA
# Processing row 669: Elmore County, ID
# Processing row 670: Kittitas County, WA
# Processing row 671: Lake County, CA
# Processing row 672: Creek County, OK
# Processing row 673: Payne County, OK
# Processing row 674: Payne County, OK
# Processing row 675: Oklahoma County, OK
# Processing row 676: Creek County, OK
# Processing row 677: Missoula County, MT
# Processing row 678: Powell County, MT
# Processing row 679: Coos County, NH
# Processing row 680: Grafton County, NH
# Processing row 681: Barton County, KS
# Processing row 682: Ellsworth County, KS
# Processing row 683: Harvey County, KS
# Processing row 684: Hodgeman County, KS
# Processing row 685: Lincoln County, KS
# Processing row 686: Morris County, KS
# Processing row 687: Ottawa County, KS
# Processing row 688: Pawnee County, KS
# Processing row 689: Reno County, KS
# Processing row 690: Rush County, KS
# Processing row 691: Russell County, KS
# Processing row 692: Stafford County, KS
# Processing row 693: Wabaunsee County, KS
# Processing row 694: Wyandotte County, KS
# Processing row 695: Pueblo of Santa Clara, NM
# Processing row 696: Burt County, NE
# Processing row 697: Butler County, NE
# Processing row 698: Colfax County, NE
# Processing row 699: Dodge County, NE
# Processing row 701: Douglas County, NE
# Processing row 702: Dundy County, NE
# Processing row 703: Fillmore County, NE
# Processing row 704: Hamilton County, NE
# Processing row 705: Hayes County, NE
# Processing row 706: Hitchcock County, NE
# Processing row 707: Howard County, NE
# Processing row 708: Keith County, NE
# Processing row 709: Platte County, NE
# Processing row 710: Polk County, NE
# Processing row 711: Red Willow County, NE
# Processing row 712: Saunders County, NE
# Processing row 713: Washington County, NE
# Processing row 714: Aurora County, SD
# Processing row 715: Bennett County, SD
# Processing row 716: Bon Homme County, SD
# Processing row 717: Brule County, SD
# Processing row 718: Buffalo County, SD
# Processing row 719: Charles Mix County, SD
# Processing row 720: Clay County, SD
# Processing row 721: Douglas County, SD
# Processing row 722: Gregory County, SD
# Processing row 723: Hand County, SD
# Processing row 724: Hanson County, SD
# Processing row 725: Hutchinson County, SD
# Processing row 726: Jackson County, SD
# Processing row 727: Lake County, SD
# Processing row 728: McCook County, SD
# Processing row 729: Miner County, SD
# Processing row 730: Minnehaha County, SD
# Processing row 731: Moody County, SD
# Processing row 732: Sanborn County, SD
# Processing row 733: Tripp County, SD
# Processing row 734: Yankton County, SD
# Processing row 735: Davison County, SD
# Processing row 736: Lincoln County, SD
# Processing row 737: Turner County, SD
# Processing row 738: Union County, SD
# Processing row 739: Adjuntas Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.163017,-66.72293260000001: No error message
# Processing row 740: Guanica Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 17.9678199,-66.93828309999999: No error message
# Processing row 741: Lajas Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.0423603,-67.055581: No error message
# Processing row 742: Las Marias Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.2517588,-66.9893366: No error message
# Processing row 743: Luquillo Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.3716049,-65.71756119999999: No error message
# Processing row 744: Maricao Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.1809934,-66.97920599999999: No error message
# Processing row 745: Naranjito Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.302174,-66.25192059999999: No error message
# Processing row 746: Orocovis Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.2276111,-66.3910084: No error message
# Processing row 747: Sabana Grande Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.0814007,-66.96535279999999: No error message
# Processing row 748: San Sebastian Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.3161884,-66.9749731: No error message
# Processing row 749: Toa Alta Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination -25.2520888,-52.0215415: No error message
# Processing row 750: Utuado Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.2673185,-66.71019460000001: No error message
# Processing row 751: Yauco Municipio, PR
# Directions API error for origin 25.771527,-80.2618756 and destination 18.0360048,-66.8605376: No error message
# Processing row 752: Adair County, KY
# Processing row 753: Allen County, KY
# Processing row 754: Ballard County, KY
# Processing row 755: Barren County, KY
# Processing row 756: Breckinridge County, KY
# Processing row 757: Carlisle County, KY
# Processing row 758: Clinton County, KY
# Processing row 759: Crittenden County, KY
# Processing row 760: Cortland County, NY
# Processing row 761: Essex County, NY
# Processing row 762: Hamilton County, NY
# Processing row 763: Lewis County, NY
# Processing row 764: St. Lawrence County, NY
# Processing row 765: Johnson County, WY
# Processing row 766: Cumberland County, KY
# Processing row 767: Edmonson County, KY
# Processing row 768: Estill County, KY
# Processing row 769: Fulton County, KY
# Processing row 770: Garrard County, KY
# Processing row 771: Graves County, KY
# Processing row 772: Grayson County, KY
# Processing row 773: Green County, KY
# Processing row 774: Harlan County, KY
# Processing row 775: Hart County, KY
# Processing row 776: Hickman County, KY
# Processing row 777: Jackson County, KY
# Processing row 778: Larue County, KY
# Processing row 779: Laurel County, KY
# Processing row 780: Lee County, KY
# Processing row 781: Leslie County, KY
# Processing row 782: Livingston County, KY
# Processing row 783: Lyon County, KY
# Processing row 784: McCracken County, KY
# Processing row 785: McCreary County, KY
# Processing row 786: McLean County, KY
# Processing row 787: Marshall County, KY
# Processing row 788: Meade County, KY
# Processing row 789: Menifee County, KY
# Processing row 790: Metcalfe County, KY
# Processing row 791: Monroe County, KY
# Processing row 792: Ohio County, KY
# Processing row 793: Owsley County, KY
# Processing row 794: Perry County, KY
# Processing row 795: Pulaski County, KY
# Processing row 796: Rockcastle County, KY
# Processing row 797: Russell County, KY
# Processing row 798: Washington County, KY
# Processing row 799: Wayne County, KY
# Processing row 800: Woodford County, KY
# Processing row 801: Greenup County, KY
# Processing row 802: Butler County, KY
# Processing row 803: Caldwell County, KY
# Processing row 804: Calloway County, KY
# Processing row 805: Christian County, KY
# Processing row 806: Clay County, KY
# Processing row 807: Hopkins County, KY
# Processing row 808: Knox County, KY
# Processing row 809: Logan County, KY
# Processing row 810: Muhlenberg County, KY
# Processing row 811: Simpson County, KY
# Processing row 812: Todd County, KY
# Processing row 813: Trigg County, KY
# Processing row 814: Warren County, KY
# Processing row 815: Whitley County, KY
# Processing row 816: Bollinger County, MO
# Processing row 817: McDonald County, MO
# Processing row 818: Madison County, MO
# Processing row 819: Oregon County, MO
# Processing row 820: Reynolds County, MO
# Processing row 821: Barry County, MO
# Processing row 822: Butler County, MO
# Processing row 823: Carter County, MO
# Processing row 824: Howell County, MO
# Processing row 825: New Madrid County, MO
# Processing row 826: Ripley County, MO
# Processing row 827: Scott County, MO
# Processing row 828: Shannon County, MO
# Processing row 829: Stoddard County, MO
# Processing row 830: Texas County, MO
# Processing row 831: Chickasaw OTSA, OK
# Processing row 832: Fort Belknap Indian Reservation, MT
# Processing row 833: Rocky Boy's Indian Reservation, MT
# Processing row 834: Blaine County, MT
# Processing row 835: Chouteau County, MT
# Processing row 836: Fergus County, MT
# Processing row 837: Hill County, MT
# Processing row 838: Judith Basin County, MT
# Processing row 839: Petroleum County, MT
# Processing row 840: Pondera County, MT
# Processing row 841: Teton County, MT
# Processing row 842: Toole County, MT
# Processing row 843: Wheatland County, MT
# Processing row 844: Allen County, KS
# Processing row 845: Anderson County, KS
# Processing row 846: Bourbon County, KS
# Processing row 847: Chautauqua County, KS
# Processing row 848: Cherokee County, KS
# Processing row 849: Elk County, KS
# Processing row 850: Greenwood County, KS
# Processing row 851: Linn County, KS
# Processing row 852: Morris County, KS
# Processing row 853: Neosho County, KS
# Processing row 854: Pottawatomie County, KS
# Processing row 855: Wilson County, KS
# Processing row 856: Woodson County, KS
# Processing row 857: Belknap County, NH
# Processing row 858: Carroll County, NH
# Processing row 859: Grafton County, NH
# Processing row 860: Rockingham Countyin PMSA 4160,4760,6450, NH
# Processing row 861: Sullivan County, NH
# Processing row 862: Anderson County, TX
# Processing row 863: Angelina County, TX
# Processing row 864: Aransas County, TX
# Directions API error for origin 29.4498705,-98.49933449999999 and destination 28.0761262,-96.9638624: No error message
# Processing row 865: Brazos County, TX
# Processing row 866: Burleson County, TX
# Processing row 867: Calhoun County, TX
# Processing row 868: Cameron County, TX
# Processing row 869: Camp County, TX
# Processing row 870: Cass County, TX
# Processing row 871: Cherokee County, TX
# Processing row 872: Colorado County, TX
# Processing row 873: DeWitt County, TX
# Processing row 874: Fayette County, TX
# Processing row 875: Freestone County, TX
# Processing row 876: Goliad County, TX
# Processing row 877: Gregg County, TX
# Processing row 878: Grimes County, TX
# Processing row 879: Hardin County, TX
# Processing row 880: Harrison County, TX
# Processing row 881: Hidalgo County, TX
# Processing row 882: Houston County, TX
# Processing row 883: Kenedy County, TX
# Processing row 884: Kleberg County, TX
# Processing row 885: Lavaca County, TX
# Processing row 886: Lee County, TX
# Processing row 887: Leon County, TX
# Processing row 888: Madison County, TX
# Processing row 889: Marion County, TX
# Processing row 890: Milam County, TX
# Processing row 891: Morris County, TX
# Processing row 892: Newton County, TX
# Processing row 893: Nueces County, TX
# Processing row 894: Panola County, TX
# Processing row 895: Refugio County, TX
# Processing row 896: Robertson County, TX
# Processing row 897: Rusk County, TX
# Processing row 898: Sabine County, TX
# Processing row 899: San Augustine County, TX
# Processing row 900: San Patricio County, TX
# Processing row 901: Tyler County, TX
# Processing row 902: Upshur County, TX
# Processing row 903: Victoria County, TX
# Processing row 904: Washington County, TX
# Processing row 905: Webb County, TX
# Processing row 906: Willacy County, TX
# Processing row 907: Austin County, TX
# Processing row 908: Bowie County, TX
# Processing row 909: Brazoria County, TX
# Processing row 910: Chambers County, TX
# Processing row 911: Fort Bend County, TX
# Processing row 912: Galveston County, TX
# Processing row 913: Harris County, TX
# Processing row 914: Jackson County, TX
# Processing row 915: Jasper County, TX
# Processing row 916: Jefferson County, TX
# Processing row 917: Liberty County, TX
# Processing row 918: Matagorda County, TX
# Processing row 919: Montgomery County, TX
# Processing row 920: Nacogdoches County, TX
# Processing row 921: Orange County, TX
# Processing row 922: Polk County, TX
# Processing row 923: San Jacinto County, TX
# Processing row 924: Shelby County, TX
# Processing row 925: Trinity County, TX
# Processing row 926: Walker County, TX
# Processing row 927: Waller County, TX
# Processing row 928: Wharton County, TX
# Processing row 929: Des Moines County, IA
# Processing row 930: Floyd County, IA
# Processing row 931: Harrison County, IA
# Processing row 932: Howard County, IA
# Processing row 933: Kossuth County, IA
# Processing row 934: Mitchell County, IA
# Processing row 935: Pocahontas County, IA
# Processing row 936: Winnebago County, IA
# Processing row 937: Winneshiek County, IA
# Processing row 938: Worth County, IA
# Processing row 939: Wright County, IA
# Processing row 940: Buena Vista County, IA
# Processing row 941: Cherokee County, IA
# Processing row 942: Clay County, IA
# Processing row 943: Dickinson County, IA
# Processing row 944: Emmet County, IA
# Processing row 945: Humboldt County, IA
# Processing row 946: Lyon County, IA
# Processing row 947: Monona County, IA
# Processing row 948: O'Brien County, IA
# Processing row 949: Osceola County, IA
# Processing row 950: Palo Alto County, IA
# Processing row 951: Plymouth County, IA
# Processing row 952: Pottawattamie County, IA
# Processing row 953: Sioux County, IA
# Processing row 954: Woodbury County, IA
# Processing row 955: Mescalero Tribe, NM
# Processing row 956: Lincoln County, NM
# Processing row 957: Otero County, NM
# Processing row 958: Rio Arriba County, NM
# Processing row 959: San Juan County, NM
# Processing row 960: Baker County, FL
# Processing row 961: Columbia County, FL
# Processing row 962: Gadsden County, FL
# Processing row 963: Hamilton County, FL
# Processing row 964: Jefferson County, FL
# Processing row 965: Lafayette County, FL
# Processing row 966: Liberty County, FL
# Processing row 967: Madison County, FL
# Processing row 968: Santa Rosa County, FL
# Processing row 969: Suwannee County, FL
# Processing row 970: Taylor County, FL
# Processing row 971: Wakulla County, FL
# Processing row 972: Leon County, FL
# Processing row 973: Kauai County, HI
# Directions API error for origin 21.3199566,-157.8706382 and destination 21.9661076,-159.5737912: No error message
# Processing row 974: Cannon County, TN
# Processing row 975: Cheatham County, TN
# Processing row 976: Giles County, TN
# Processing row 977: Hamilton County, TN
# Processing row 978: Jackson County, TN
# Processing row 979: Macon County, TN
# Processing row 980: Maury County, TN
# Processing row 981: Montgomery County, TN
# Processing row 982: Polk County, TN
# Processing row 983: Smith County, TN
# Processing row 984: Sumner County, TN
# Processing row 985: Warren County, TN
# Processing row 986: Roger Mills County, OK
# Processing row 987: Woods County, OK
# Processing row 988: Muskogee County, OK
# Processing row 989: Blaine County, OK
# Processing row 990: Caddo County, OK
# Processing row 991: Custer County, OK
# Processing row 992: Delaware County, OK
# Processing row 993: Jackson County, OK
# Processing row 994: Mayes County, OK
# Processing row 995: Rogers County, OK
# Processing row 996: Hancock County, MS
# Processing row 997: Hinds County, MS
# Processing row 998: Humphreys County, MS
# Processing row 999: Madison County, MS
# Processing row 1000: Neshoba County, MS
# Processing row 1001: Scott County, MS
# Processing row 1002: Idaho County, ID
# Processing row 1003: Lewis County, ID
# Processing row 1004: Shoshone County, ID
# Processing row 1005: Carroll County, AR
# Processing row 1006: Nevada County, AR
# Processing row 1007: Sharp County, AR
# Processing row 1008: Greene County, AR
# Processing row 1009: Baxter County, AR
# Processing row 1010: Benton County, AR
# Processing row 1011: Boone County, AR
# Processing row 1012: Fulton County, AR
# Processing row 1013: Madison County, AR
# Processing row 1014: Marion County, AR
# Processing row 1015: Randolph County, AR
# Processing row 1016: Brooke County, WV
# Processing row 1017: Doddridge County, WV
# Processing row 1018: Gilmer County, WV
# Processing row 1019: Lincoln County, WV
# Processing row 1020: Tyler County, WV
# Processing row 1021: Kanawha County, WV
# Processing row 1022: Roane County, WV
# Processing row 1023: Wood County, WV
# Processing row 1024: Boone County, WV
# Processing row 1025: Hancock County, WV
# Processing row 1026: Marshall County, WV
# Processing row 1027: Ohio County, WV
# Processing row 1028: Wetzel County, WV
# Processing row 1029: Banner County, NE
# Processing row 1030: Cheyenne County, NE
# Processing row 1031: Dawes County, NE
# Processing row 1032: Garden County, NE
# Processing row 1033: Kimball County, NE
# Processing row 1034: Morrill County, NE
# Processing row 1035: Scotts Bluff County, NE
# Processing row 1036: Sioux County, NE
# Processing row 1037: Cumberland County, ME
# Processing row 1038: York Countyin MSA 6400,6450, ME
# Processing row 1039: Buena Vista County, IA
# Processing row 1040: Butler County, IA
# Processing row 1041: Calhoun County, IA
# Processing row 1042: Cherokee County, IA
# Processing row 1043: Clay County, IA
# Processing row 1044: Dallas County, IA
# Processing row 1045: Franklin County, IA
# Processing row 1046: Hamilton County, IA
# Processing row 1047: Hancock County, IA
# Processing row 1048: Harrison County, IA
# Processing row 1049: Humboldt County, IA
# Processing row 1050: Iowa County, IA
# Processing row 1051: Jackson County, IA
# Processing row 1052: Kossuth County, IA
# Processing row 1053: Marshall County, IA
# Processing row 1054: Mitchell County, IA
# Processing row 1055: Muscatine County, IA
# Processing row 1056: Pottawattamie County, IA
# Processing row 1057: Poweshiek County, IA
# Processing row 1058: Shelby County, IA
# Processing row 1059: Tama County, IA
# Processing row 1060: Wright County, IA
# Processing row 1061: Adair County, IA
# Processing row 1062: Adams County, IA
# Processing row 1063: Cedar County, IA
# Processing row 1064: Jasper County, IA
# Processing row 1065: Montgomery County, IA
# Processing row 1066: Polk County, IA
# Processing row 1067: Story County, IA
# Processing row 1068: Brooke County, WV
# Processing row 1069: Hancock County, WV
# Processing row 1070: Preston County, WV
# Processing row 1071: Tyler County, WV
# Processing row 1072: Boone County, WV
# Processing row 1073: Cabell County, WV
# Processing row 1074: Fayette County, WV
# Processing row 1075: Kanawha County, WV
# Processing row 1076: Lincoln County, WV
# Processing row 1077: Nicholas County, WV
# Processing row 1078: Putnam County, WV
# Processing row 1079: Wayne County, WV
# Processing row 1080: Marshall County, WV
# Processing row 1081: Ohio County, WV
# Processing row 1082: Wetzel County, WV
# Processing row 1083: Boyd County, KY
# Processing row 1084: Carter County, KY
# Processing row 1085: Fayette County, KY
# Processing row 1086: Greenup County, KY
# Processing row 1087: Henry County, KY
# Processing row 1088: Jefferson County, KY
# Processing row 1089: Jessamine County, KY
# Processing row 1090: Mason County, KY
# Processing row 1091: Oldham County, KY
# Processing row 1092: Union County, KY
# Processing row 1093: Whitley County, KY
# Processing row 1094: Bailey County, TX
# Processing row 1095: Baylor County, TX
# Processing row 1096: Blanco County, TX
# Processing row 1097: Bosque County, TX
# Processing row 1098: Bowie County, TX
# Processing row 1099: Brown County, TX
# Processing row 1100: Caldwell County, TX
# Processing row 1101: Cass County, TX
# Processing row 1102: Cherokee County, TX
# Processing row 1103: Clay County, TX
# Processing row 1104: Cochran County, TX
# Processing row 1105: Coke County, TX
# Processing row 1106: Coleman County, TX
# Processing row 1107: Concho County, TX
# Processing row 1108: Delta County, TX
# Processing row 1109: Fannin County, TX
# Processing row 1110: Freestone County, TX
# Processing row 1111: Gonzales County, TX
# Processing row 1112: Grimes County, TX
# Processing row 1113: Hamilton County, TX
# Processing row 1114: Hays County, TX
# Processing row 1115: Hill County, TX
# Processing row 1116: Hopkins County, TX
# Processing row 1117: Houston County, TX
# Processing row 1118: Lampasas County, TX
# ...
# Processing row 51270: Amherst County, VA
# Processing row 51271: Appomattox County, VA
# Processing row 51272: Arlington County, VA
# Processing row 51273: Augusta County, VA
# Processing row 51274: Bath County, VA
# Processing row 51275: Bedford County, VA
# Processing row 51276: Bland County, VA
# Processing row 51277: Botetourt County, VA
# Processing row 51278: Brunswick County, VA
# Processing row 51279: Buchanan County, VA
# Processing row 51280: Buckingham County, VA
# Processing row 51281: Campbell County, VA
# Processing row 51282: Caroline County, VA
# Processing row 51283: Carroll County, VA
# Processing row 51284: Charles City County, VA
# Processing row 51285: Charlotte County, VA
# Processing row 51286: Chesterfield County, VA
# Processing row 51287: Clarke County, VA
# Processing row 51288: Craig County, VA
# Processing row 51289: Culpeper County, VA
# Processing row 51290: Cumberland County, VA
# Processing row 51291: Dickenson County, VA
# Processing row 51292: Dinwiddie County, VA
# Processing row 51293: Essex County, VA
# Processing row 51294: Fairfax County, VA
# Processing row 51295: Fauquier County, VA
# Processing row 51296: Floyd County, VA
# Processing row 51297: Fluvanna County, VA
# Processing row 51298: Franklin County, VA
# Processing row 51299: Frederick County, VA
# Processing row 51300: Giles County, VA
# Processing row 51301: Goochland County, VA
# Processing row 51302: Grayson County, VA
# Processing row 51303: Greene County, VA
# Processing row 51304: Greensville County, VA
# Processing row 51305: Halifax County, VA
# Processing row 51306: Hanover County, VA
# Processing row 51307: Henrico County, VA
# Processing row 51308: Henry County, VA
# Processing row 51309: Highland County, VA
# Processing row 51310: Isle of Wight County, VA
# Processing row 51311: James City County, VA
# Processing row 51312: King and Queen County, VA
# Processing row 51313: King George County, VA
# Processing row 51314: King William County, VA
# Processing row 51315: Lancaster County, VA
# Processing row 51316: Lee County, VA
# Processing row 51317: Loudoun County, VA
# Processing row 51318: Louisa County, VA
# Processing row 51319: Lunenburg County, VA
# Processing row 51320: Madison County, VA
# Processing row 51321: Mecklenburg County, VA
# Processing row 51322: Middlesex County, VA
# Processing row 51323: Montgomery County, VA
# Processing row 51324: Nelson County, VA
# Processing row 51325: New Kent County, VA
# Processing row 51326: Northampton County, VA
# Processing row 51327: Northumberland County, VA
# Processing row 51328: Nottoway County, VA
# Processing row 51329: Orange County, VA
# Processing row 51330: Page County, VA
# Processing row 51331: Patrick County, VA
# Processing row 51332: Pittsylvania County, VA
# Processing row 51333: Powhatan County, VA
# Processing row 51334: Prince Edward County, VA
# Processing row 51335: Prince George County, VA
# Processing row 51336: Prince William County, VA
# Processing row 51337: Pulaski County, VA
# Processing row 51338: Rappahannock County, VA
# Processing row 51339: Richmond County, VA
# Processing row 51340: Roanoke County, VA
# Processing row 51341: Rockbridge County, VA
# Processing row 51342: Rockingham County, VA
# Processing row 51343: Russell County, VA
# Processing row 51344: Scott County, VA
# Processing row 51345: Shenandoah County, VA
# Processing row 51346: Smyth County, VA
# Processing row 51347: Southampton County, VA
# Processing row 51348: Spotsylvania County, VA
# Processing row 51349: Stafford County, VA
# Processing row 51350: Surry County, VA
# Processing row 51351: Sussex County, VA
# Processing row 51352: Tazewell County, VA
# Processing row 51353: Warren County, VA
# Processing row 51354: Washington County, VA
# Processing row 51355: Westmoreland County, VA
# Processing row 51356: Wise County, VA
# Processing row 51357: Wythe County, VA
# Processing row 51358: York County, VA
# Processing row 51359: Alexandria, VA
# Processing row 51360: Colonial Heights, VA
# Processing row 51361: Danville, VA
# Processing row 51362: Emporia, VA
# Processing row 51363: Fairfax, VA
# Processing row 51364: Franklin, VA
# Processing row 51365: Fredericksburg, VA
# Processing row 51366: Hopewell, VA
# Processing row 51367: Manassas, VA
# Processing row 51368: Newport News, VA
# Processing row 51369: Petersburg, VA
# Processing row 51370: Richmond, VA
# Processing row 51371: Suffolk, VA
# Processing row 51372: Williamsburg, VA
# Processing row 51373: Cherokee County, AL
# Processing row 51374: DeKalb County, AL
# Processing row 51375: Jackson County, AL
# Processing row 51376: Aleutians East Borough, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 55.3601426,-161.6757637: No error message
# Processing row 51377: Anchorage Borough, AK
# Processing row 51378: Bethel Census Area, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 61.09344600000001,-160.8640774: No error message
# Processing row 51379: Bristol Bay Borough, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 58.7578504,-156.7792687: No error message
# Processing row 51380: Denali Borough, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 63.82571729999999,-149.7317834: No error message
# Processing row 51381: Dillingham Census Area, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 59.80677919999999,-157.7242585: No error message
# Processing row 51382: Fairbanks North Star Borough, AK
# Processing row 51383: Kenai Peninsula Borough, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 60.0858486,-151.3822641: No error message
# Processing row 51384: Kodiak Island Borough, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 57.53693430000001,-153.2659352: No error message
# Processing row 51385: Lake and Peninsula Borough, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 58.0458356,-156.5982286: No error message
# Processing row 51386: Matanuska-Susitna Borough, AK
# Processing row 51387: Southeast Fairbanks Census Area, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 63.9603869,-143.6296998: No error message
# Processing row 51388: Valdez-Cordova Census Area, AK
# Processing row 51389: Wade Hampton Census Area, AK
# Directions API error for origin 61.21543519999999,-149.8929531 and destination 62.1458336,-162.8919191: No error message
# Processing row 51390: Decatur County, GA
# Processing row 51391: Turner County, GA
# Processing row 51392: Colquitt County, GA
# Processing row 51393: Grady County, GA
# Processing row 51394: Mitchell County, GA
# Processing row 51395: Tift County, GA
# Processing row 51396: Bienville Parish, LA
# Processing row 51397: Claiborne Parish, LA
# Processing row 51398: Lincoln Parish, LA
# Processing row 51399: Ouachita Parish, LA
# Processing row 51400: Richland Parish, LA
# Processing row 51401: Union Parish, LA
# Processing row 51402: Webster Parish, LA
# Processing row 51403: West Carroll Parish, LA
# Processing row 51404: Edgefield County, SC
# Processing row 51405: Abbeville County, SC
# Processing row 51406: Aiken County, SC
# Processing row 51407: Allendale County, SC
# Processing row 51408: Bamberg County, SC
# Processing row 51409: Barnwell County, SC
# Processing row 51410: Berkeley County, SC
# Processing row 51411: Calhoun County, SC
# Processing row 51412: Charleston County, SC
# Processing row 51413: Cherokee County, SC
# Processing row 51414: Chester County, SC
# Processing row 51415: Chesterfield County, SC
# Processing row 51416: Clarendon County, SC
# Processing row 51417: Colleton County, SC
# Processing row 51418: Darlington County, SC
# Processing row 51419: Dillon County, SC
# Processing row 51420: Dorchester County, SC
# Processing row 51421: Fairfield County, SC
# Processing row 51422: Florence County, SC
# Processing row 51423: Georgetown County, SC
# Processing row 51424: Greenwood County, SC
# Processing row 51425: Kershaw County, SC
# Processing row 51426: Lancaster County, SC
# Processing row 51427: Laurens County, SC
# Processing row 51428: Lee County, SC
# Processing row 51429: Lexington County, SC
# Processing row 51430: McCormick County, SC
# Processing row 51431: Marion County, SC
# Processing row 51432: Marlboro County, SC
# Processing row 51433: Newberry County, SC
# Processing row 51434: Orangeburg County, SC
# Processing row 51435: Richland County, SC
# Processing row 51436: Saluda County, SC
# Processing row 51437: Spartanburg County, SC
# Processing row 51438: Sumter County, SC
# Processing row 51439: Union County, SC
# Processing row 51440: Williamsburg County, SC
# Processing row 51441: York County, SC
# Processing row 51442: Alamance County, NC
# Processing row 51443: Anson County, NC
# Processing row 51444: Cabarrus County, NC
# Processing row 51445: Caswell County, NC
# Processing row 51446: Chatham County, NC
# Processing row 51447: Davidson County, NC
# Processing row 51448: Durham County, NC
# Processing row 51449: Edgecombe County, NC
# Processing row 51450: Franklin County, NC
# Processing row 51451: Granville County, NC
# Processing row 51452: Guilford County, NC
# Processing row 51453: Halifax County, NC
# Processing row 51454: Harnett County, NC
# Processing row 51455: Hoke County, NC
# Processing row 51456: Johnston County, NC
# Processing row 51457: Lee County, NC
# Processing row 51458: Mecklenburg County, NC
# Processing row 51459: Montgomery County, NC
# Processing row 51460: Moore County, NC
# Processing row 51461: Nash County, NC
# Processing row 51462: Northampton County, NC
# Processing row 51463: Orange County, NC
# Processing row 51464: Person County, NC
# Processing row 51465: Randolph County, NC
# Processing row 51466: Richmond County, NC
# Processing row 51467: Rockingham County, NC
# Processing row 51468: Scotland County, NC
# Processing row 51469: Stanly County, NC
# Processing row 51470: Union County, NC
# Processing row 51471: Vance County, NC
# Processing row 51472: Wake County, NC
# Processing row 51473: Warren County, NC
# Processing row 51474: Wilson County, NC
# Processing row 51475: Banks County, GA
# Processing row 51476: Barrow County, GA
# Processing row 51477: Bartow County, GA
# Processing row 51478: Butts County, GA
# Processing row 51479: Carroll County, GA
# Processing row 51480: Catoosa County, GA
# Processing row 51481: Chattooga County, GA
# Processing row 51482: Cherokee County, GA
# Processing row 51483: Clarke County, GA
# Processing row 51484: Cobb County, GA
# Processing row 51485: Dawson County, GA
# Processing row 51486: DeKalb County, GA
# Processing row 51487: Douglas County, GA
# Processing row 51488: Elbert County, GA
# Processing row 51489: Fannin County, GA
# Processing row 51490: Floyd County, GA
# Processing row 51491: Forsyth County, GA
# Processing row 51492: Franklin County, GA
# Processing row 51493: Fulton County, GA
# Processing row 51494: Gilmer County, GA
# Processing row 51495: Gordon County, GA
# Processing row 51496: Greene County, GA
# Processing row 51497: Gwinnett County, GA
# Processing row 51498: Habersham County, GA
# Processing row 51499: Hall County, GA
# Processing row 51500: Haralson County, GA
# Processing row 51501: Hart County, GA
# Processing row 51502: Henry County, GA
# Processing row 51503: Jackson County, GA
# Processing row 51504: Jasper County, GA
# Processing row 51505: Jones County, GA
# Processing row 51506: Lamar County, GA
# Processing row 51507: Lumpkin County, GA
# Processing row 51508: Monroe County, GA
# Processing row 51509: Newton County, GA
# Processing row 51510: Oconee County, GA
# Processing row 51511: Oglethorpe County, GA
# Processing row 51512: Paulding County, GA
# Processing row 51513: Pickens County, GA
# Processing row 51514: Pike County, GA
# Processing row 51515: Rabun County, GA
# Processing row 51516: Rockdale County, GA
# Processing row 51517: Spalding County, GA
# Processing row 51518: Stephens County, GA
# Processing row 51519: Taliaferro County, GA
# Processing row 51520: Union County, GA
# Processing row 51521: Upson County, GA
# Processing row 51522: Walker County, GA
# Processing row 51523: Walton County, GA
# Processing row 51524: White County, GA
# Processing row 51525: Wilkes County, GA
# Processing row 51526: Ballard County, KY
# Processing row 51527: Breckinridge County, KY
# Processing row 51528: Carlisle County, KY
# Processing row 51529: Livingston County, KY
# Processing row 51530: Spencer County, KY
# Processing row 51531: Hancock County, KY
# Processing row 51532: Henderson County, KY
# Processing row 51533: Crittenden County, KY
# Processing row 51534: Daviess County, KY
# Processing row 51535: Hopkins County, KY
# Processing row 51536: Webster County, KY
# Processing row 51537: St. Croix Island County-equivalent, VI
# Directions API error for origin 25.771527,-80.2618756 and destination 17.7245968,-64.83479919999999: No error message
# Processing row 51538: St. John Island County-equivalent, VI
# Directions API error for origin 25.771527,-80.2618756 and destination 18.3368114,-64.7280952: No error message
# Processing row 51539: St. Thomas Island County-equivalent, VI
# Directions API error for origin 25.771527,-80.2618756 and destination 18.3380965,-64.8940946: No error message
# Processing row 51540: Androscoggin County, ME
# Processing row 51541: Cumberland County, ME
# Processing row 51542: Kennebec County, ME
# Processing row 51543: Oxford County, ME
# Processing row 51544: Somerset County, ME
# Processing row 51545: Bennington County, VT
# Processing row 51546: Caledonia County, VT
# Processing row 51547: Essex County, VT
# Processing row 51548: Lamoille County, VT
# Processing row 51549: Orange County, VT
# Processing row 51550: Orleans County, VT
# Processing row 51551: Rutland County, VT
# Processing row 51552: Washington County, VT
# Processing row 51553: Windham County, VT
# Processing row 51554: Windsor County, VT
# Processing row 51555: Flagler County, FL
# Processing row 51556: Collier County, FL
# Processing row 51557: Glades County, FL
# Processing row 51558: Hendry County, FL
# Processing row 51559: Highlands County, FL
# Processing row 51560: Orange County, FL
# Processing row 51561: Osceola County, FL
# Processing row 51562: Polk County, FL
# Processing row 51563: Seminole County, FL
# Processing row 51564: Brevard County, FL
# Processing row 51565: Broward County, FL
# Processing row 51566: Indian River County, FL
# Processing row 51567: Martin County, FL
# Processing row 51568: Dade County, FL
# Directions API error for origin 25.771527,-80.2618756 and destination 25.5516034,-80.6326916: No error message
# Processing row 51569: Monroe County, FL
# Directions API error for origin 25.771527,-80.2618756 and destination 25.2974483,-81.0754657: No error message
# Processing row 51570: Okeechobee County, FL
# Processing row 51571: Palm Beach County, FL
# Processing row 51572: St. Lucie County, FL
# Processing row 51573: Volusia County, FL
# Processing row 51574: Belknap County, NH
# Processing row 51575: Cheshire County, NH
# Processing row 51576: Grafton County, NH
# Processing row 51577: Cochise County, AZ
# Processing row 51578: Maricopa County, AZ
#    disasterNumber state  year incidentType       designatedArea  \
# 0            5530    NV  2024         Fire      Washoe (County)
# 1            5529    OR  2024         Fire  Washington (County)
# 2            5528    OR  2024         Fire   Jefferson (County)
# 3            5527    OR  2024         Fire   Deschutes (County)
# 4            5526    CO  2024         Fire   Jefferson (County)
#
#            disaster_area                  EOC Disaster Lat Disaster Lng  \
# 0      Washoe County, NV  Carson City Hub, NV    40.560839  -119.603549
# 1  Washington County, OR      Olympia Hub, WA    45.546962  -123.138602
# 2   Jefferson County, OR      Olympia Hub, WA    44.667332  -121.178579
# 3   Deschutes County, OR      Olympia Hub, WA     43.83251  -121.261654
# 4   Jefferson County, CO       Denver Hub, CO     39.58003  -105.266293
#
#      EOC Lat     EOC Lng Distance (km) Duration (minutes)
# 0   39.15134 -119.741247       250.342         221.866667
# 1  47.038257 -122.901219       223.795         133.516667
# 2  47.038257 -122.901219       359.142         229.633333
# 3  47.038257 -122.901219       470.411         313.866667
# 4  39.740402 -104.997531        43.354               35.1

# %%
filtered_df
# Out:
#        disasterNumber state  year  incidentType       designatedArea  \
# 0                5530    NV  2024          Fire      Washoe (County)
# 1                5529    OR  2024          Fire  Washington (County)
# 2                5528    OR  2024          Fire   Jefferson (County)
# 3                5527    OR  2024          Fire   Deschutes (County)
# 4                5526    CO  2024          Fire   Jefferson (County)
# ...               ...   ...   ...           ...                  ...
# 51574            1305    NH  2000     Hurricane     Belknap (County)
# 51575            1305    NH  2000     Hurricane    Cheshire (County)
# 51576            1305    NH  2000     Hurricane     Grafton (County)
# 51577            1304    AZ  2000  Severe Storm     Cochise (County)
# 51578            1304    AZ  2000  Severe Storm    Maricopa (County)
#
#                disaster_area                  EOC Disaster Lat Disaster Lng  \
# 0          Washoe County, NV  Carson City Hub, NV    40.560839  -119.603549
# 1      Washington County, OR      Olympia Hub, WA    45.546962  -123.138602
# 2       Jefferson County, OR      Olympia Hub, WA    44.667332  -121.178579
# 3       Deschutes County, OR      Olympia Hub, WA     43.83251  -121.261654
# 4       Jefferson County, CO       Denver Hub, CO     39.58003  -105.266293
# ...                      ...                  ...          ...          ...
# 51574     Belknap County, NH   Montpelier Hub, VT    43.502425   -71.407394
# 51575    Cheshire County, NH       Albany Hub, NY    42.925938   -72.236379
# 51576     Grafton County, NH   Montpelier Hub, VT    43.908793   -71.825994
# 51577     Cochise County, AZ      Phoenix Hub, AZ    31.828458  -109.949686
# 51578    Maricopa County, AZ      Phoenix Hub, AZ    33.291797  -112.429146
#
#          EOC Lat     EOC Lng Distance (km) Duration (minutes)
# 0       39.15134 -119.741247       250.342         221.866667
# 1      47.038257 -122.901219       223.795         133.516667
# 2      47.038257 -122.901219       359.142         229.633333
# 3      47.038257 -122.901219       470.411         313.866667
# 4      39.740402 -104.997531        43.354               35.1
# ...          ...         ...           ...                ...
# 51574  44.262814  -72.582793       195.488         135.233333
# 51575  42.684315  -73.816271       167.051         137.633333
# 51576  44.262814  -72.582793       115.936              104.0
# 51577  33.456182 -111.979376       309.532             193.95
# 51578  33.456182 -111.979376        64.572          48.333333
#
# [47776 rows x 13 columns]

# %%
filtered_df.isnull().sum()
# Out:
# disasterNumber           0
# state                    0
# year                     0
# incidentType             0
# designatedArea           0
# disaster_area            0
# EOC                    381
# Disaster Lat           381
# Disaster Lng           381
# EOC Lat                381
# EOC Lng                381
# Distance (km)         2796
# Duration (minutes)    2796
# dtype: int64

# %%
filtered_df = filtered_df.dropna()

# %%
filtered_df.to_csv('../data/clean/fema_df_coords.csv')
