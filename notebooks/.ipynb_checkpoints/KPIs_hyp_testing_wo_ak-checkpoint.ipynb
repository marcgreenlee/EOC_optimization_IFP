# %%
import pandas as pd
import seaborn as sns
import warnings # Suppress all warnings 
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import shapiro
from scipy.stats import spearmanr
from scipy.stats import f_oneway
warnings.filterwarnings("ignore")

# %%
data = '../data/clean/fema_df_coords.csv'

# %%
fema_df = pd.read_csv(data)
fema_df.drop(columns = 'Unnamed: 0', inplace = True)
fema_df
# Out:
#        disasterNumber state  year  incidentType       designatedArea  \
# 0                5530    NV  2024          Fire      Washoe (County)
# 1                5529    OR  2024          Fire  Washington (County)
# 2                5528    OR  2024          Fire   Jefferson (County)
# 3                5527    OR  2024          Fire   Deschutes (County)
# 4                5526    CO  2024          Fire   Jefferson (County)
# ...               ...   ...   ...           ...                  ...
# 47771            1305    NH  2000     Hurricane     Belknap (County)
# 47772            1305    NH  2000     Hurricane    Cheshire (County)
# 47773            1305    NH  2000     Hurricane     Grafton (County)
# 47774            1304    AZ  2000  Severe Storm     Cochise (County)
# 47775            1304    AZ  2000  Severe Storm    Maricopa (County)
#
#                disaster_area                  EOC  Disaster Lat  Disaster Lng  \
# 0          Washoe County, NV  Carson City Hub, NV     40.560839   -119.603549
# 1      Washington County, OR      Olympia Hub, WA     45.546962   -123.138602
# 2       Jefferson County, OR      Olympia Hub, WA     44.667332   -121.178579
# 3       Deschutes County, OR      Olympia Hub, WA     43.832510   -121.261654
# 4       Jefferson County, CO       Denver Hub, CO     39.580030   -105.266293
# ...                      ...                  ...           ...           ...
# 47771     Belknap County, NH   Montpelier Hub, VT     43.502425    -71.407394
# 47772    Cheshire County, NH       Albany Hub, NY     42.925938    -72.236379
# 47773     Grafton County, NH   Montpelier Hub, VT     43.908793    -71.825994
# 47774     Cochise County, AZ      Phoenix Hub, AZ     31.828458   -109.949686
# 47775    Maricopa County, AZ      Phoenix Hub, AZ     33.291797   -112.429146
#
#          EOC Lat     EOC Lng  Distance (km)  Duration (minutes)
# 0      39.151340 -119.741247        250.342          221.866667
# 1      47.038257 -122.901219        223.795          133.516667
# 2      47.038257 -122.901219        359.142          229.633333
# 3      47.038257 -122.901219        470.411          313.866667
# 4      39.740402 -104.997531         43.354           35.100000
# ...          ...         ...            ...                 ...
# 47771  44.262814  -72.582793        195.488          135.233333
# 47772  42.684315  -73.816271        167.051          137.633333
# 47773  44.262814  -72.582793        115.936          104.000000
# 47774  33.456182 -111.979376        309.532          193.950000
# 47775  33.456182 -111.979376         64.572           48.333333
#
# [47776 rows x 13 columns]

# %%
fema_df = fema_df.dropna()

# %% [markdown]
# # KPI 1: Incident Frequency vs Distance from EOC

# %% [markdown]
# Objective: Test whether incident frequency is related to distance from the nearest EOC.

# %% [markdown]
# Hypotheses:
#
# - Null Hypothesis (H0): There is no significant relationship between incident frequency and average distance from EOCs for different disaster areas.
# - Alternative Hypothesis (H1): There is a significant relationship between incident frequency and average distance from EOCs for different disaster areas.

# %%
#Group the data by disaster_area to calculate incident frequency and average distance 
incident_freq_area = fema_df.groupby('disaster_area').size().reset_index(name='incident_frequency')
avg_distance_area = fema_df.groupby('disaster_area')['Distance (km)'].mean().reset_index()
freq_distance_df_area = pd.merge(incident_freq_area, avg_distance_area, on='disaster_area')
freq_distance_df_area
# Out:
#                                           disaster_area  incident_frequency  \
# 0                                  Abbeville County, SC                  18
# 1     Absentee Shawnee-Citizens Band of Potawatomi T...                   3
# 2                                     Acadia Parish, LA                  34
# 3                                   Accomack County, VA                  11
# 4                                        Ada County, ID                   5
# ...                                                 ...                 ...
# 3820                                  Zavala County, TX                  13
# 3821                  Zia Pueblo Indian Reservation, NM                   2
# 3822                                 Ziebach County, SD                  15
# 3823                 Zuni Pueblo Indian Reservation, AZ                   2
# 3824                 Zuni Pueblo Indian Reservation, NM                   3
#
#       Distance (km)
# 0        164.367000
# 1        105.513000
# 2        127.950000
# 3        284.467000
# 4         11.014000
# ...             ...
# 3820     152.468923
# 3821     113.524000
# 3822     198.489000
# 3823     229.730000
# 3824     352.435000
#
# [3825 rows x 3 columns]

# %%
#Visualize relationship

plt.figure(figsize=(12, 6))
sns.scatterplot(data=freq_distance_df_area, x='incident_frequency', y='Distance (km)', hue='disaster_area', palette='Set3', size='incident_frequency', sizes=(50, 300), legend=None)

# Improve readability
plt.title("Incident Frequency vs. Average Distance to EOC by Disaster Area")
plt.xlabel("Incident Frequency")
plt.ylabel("Average Distance (km)")

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Test for normality
shapiro_freq = shapiro(freq_distance_df_area['incident_frequency'])
shapiro_dist = shapiro(freq_distance_df_area['Distance (km)'])

print(f"Incident Frequency Normality: {shapiro_freq}")
print(f"Distance Normality: {shapiro_dist}")
# Out:
# Incident Frequency Normality: ShapiroResult(statistic=0.949224851011363, pvalue=1.8189599681841283e-34)
# Distance Normality: ShapiroResult(statistic=0.7970509114340634, pvalue=1.772513780419178e-56)

# %% [markdown]
# These results indicate the distribution of the two variables is not normal.

# %%
#Given the distribution of our data is not normal, we aim to see  whether there is a monotonic relationship between two variables

# Calculate Spearman's rank correlation
spearman_corr, p_value = spearmanr(freq_distance_df_area['incident_frequency'], freq_distance_df_area['Distance (km)'])

# Display the results
print(f"Spearman's Rank Correlation: {spearman_corr}, p-value: {p_value}")
# Out:
# Spearman's Rank Correlation: -0.055625842165367666, p-value: 0.0005778385050677615

# %% [markdown]
# Spearman’s Rank Correlation coefficient of -0.0556 suggests a very weak negative relationship between incident frequency and distance from the EOC.  The relationship is weak and not significant in a practical sense.
# p-value: The p-value of 0.0005778 is less than 0.05, which indicates that the result is statistically significant. However, due to the very small magnitude of the correlation (-0.0556), the relationship is weak and likely not meaningful for practical purposes.

# %% [markdown]
# Conclusion: the weak negative correlation between incident frequency and distance from the EOC could indicate that EOC location selection may not currently prioritize proximity to disaster areas with higher incident frequencies. This could be an opportunity for improvement in the decision-making process for EOC placement.

# %% [markdown]
# # KPI 2: Incident Type vs. Travel Time

# %% [markdown]
# Different types of incidents may require different response times. If certain incident types consistently result in longer travel times, this could indicate that the EOCs are not equipped to handle those incidents effectively or that additional resources are needed closer to those areas.
#
# Objective: Test whether travel time varies significantly by incident type.

# %% [markdown]
# Hyptheses:
#
# Null Hypothesis (H0): Travel time does not vary by incident type.
#
# Alternative Hypothesis (H1): Travel time varies significantly by incident type, suggesting logistical inefficiencies.

# %%
#Group the data
travel_time_data = fema_df[['incidentType', 'Duration (minutes)']]

# %%
#Visualize the relationship

plt.figure(figsize=(14, 8))

# Create a violin plot
sns.violinplot(data=travel_time_data, x='incidentType', y='Duration (minutes)', palette='coolwarm')
plt.xticks(rotation=45, ha="right")
plt.title('Travel Time Distribution by Incident Type')

# Adjust the layout to make sure labels fit within the plot
plt.tight_layout()

plt.show()

# %%
# conduct ANOVA, appropriate for this analysis because it allows to compare the means of travel times for multiple incident types
#and assess whether the differences are statistically significant.

groups = [travel_time_data[travel_time_data['incidentType'] == t]['Duration (minutes)'] for t in travel_time_data['incidentType'].unique()]
f_stat, p_value = f_oneway(*groups)
print(f"F-statistic: {f_stat}, P-value: {p_value}")
# Out:
# F-statistic: 60.586594675777505, P-value: 5.548777852666011e-241

# %% [markdown]
# F-statistic (60.59): This value represents the ratio of the variance between the groups (incident types) to the variance within the groups. A higher F-statistic indicates a larger difference between the groups relative to the variability within each group, which suggests that the means of travel times across incident types are not equal.
# P-value (5.55e-241): This is an extremely small p-value. This indicates a strong rejection of the null hypothesis, suggesting that the differences in travel times across incident types are statistically significant.

# %% [markdown]
# Conclussion: By evaluating how travel time varies by incident type, we may uncover patterns that suggest some EOCs are better prepared (i.e., located more strategically) for certain types of incidents, while others may be more distant or less able to respond quickly. This information could be used to highlight areas for improvement in EOC location decisions.
# If some incident types consistently require longer travel times, it may suggest that EOCs are not ideally positioned to handle these types of incidents, particularly in certain regions. This would be a key factor when assessing the overall "optimality" of EOC locations.

# %% [markdown]
# # KPI 3: State-level Travel Time Disparities

# %% [markdown]
# Analyzing travel time disparities across states provides a regional perspective, helping to identify underserved areas where response times are unreasonably long. This could highlight specific regions that would benefit from additional EOCs or better routing strategies.

# %% [markdown]
# Objective: Test whether travel times vary significantly across states.

# %% [markdown]
# Hypotheses:
#
# Null Hypothesis (H0): Travel times do not vary significantly across states.
#
# Alternative Hypothesis (H1): Travel times vary significantly across states, indicating regional disparities in EOC coverage.

# %%
#Group data
state_travel_data = fema_df[['state', 'Duration (minutes)']]

# %%
#Visualize relationship
avg_travel_time = state_travel_data.groupby('state')['Duration (minutes)'].mean().reset_index()

# Sort by travel time
avg_travel_time = avg_travel_time.sort_values(by='Duration (minutes)', ascending=False)

# Create the bar plot
sns.barplot(data=avg_travel_time, x='state', y='Duration (minutes)', palette='coolwarm')
plt.xticks(rotation=45)  
plt.title('Average Travel Time by State')
plt.ylabel('Duration (minutes)')
plt.xlabel('State')
plt.show()

# %%
#ANOVA statistical test
groups = [state_travel_data[state_travel_data['state'] == s]['Duration (minutes)'] for s in state_travel_data['state'].unique()]
f_stat, p_value = f_oneway(*groups)
print(f"F-statistic: {f_stat}, P-value: {p_value}")
# Out:
# F-statistic: 285.33121039871907, P-value: 0.0

# %% [markdown]
# This high F-statistic indicates that there is substantial variance in travel times between at least some states, relative to the variance within states.
#
# A p-value of 0 means that the differences in travel times across states are statistically significant. In other words, the likelihood of observing these differences due to random chance is negligible.

# %% [markdown]
# Conclusion: With this test we have statistically proven that average response/travel times are different across states. These disparities could inform recommendations about reallocating resources or creating new EOCs in underserved areas.

# %% [markdown]
# # KPIs W/O Alaska
