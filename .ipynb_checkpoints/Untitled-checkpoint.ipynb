# %%
# !conda install -y streamlit pandas geopandas matplotlib seaborn
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - geopandas
#     - matplotlib
#     - pandas
#     - seaborn
#     - streamlit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.8.1               |     pyhd8ed1ab_0          29 KB  conda-forge
#     ca-certificates-2024.12.14 |       hf0a4a13_0         153 KB  conda-forge
#     cairo-1.16.0               |       h302bd0f_5         1.0 MB
#     certifi-2024.12.14         |     pyhd8ed1ab_0         158 KB  conda-forge
#     click-plugins-1.1.1        |     pyhd8ed1ab_1          12 KB  conda-forge
#     cligj-0.7.2                |     pyhd8ed1ab_2          12 KB  conda-forge
#     conda-24.11.1              |  py312h81bd7bf_0         1.1 MB  conda-forge
#     fiona-1.9.5                |  py312hd77ebd4_0         905 KB
#     folium-0.19.2              |     pyhd8ed1ab_0          78 KB  conda-forge
#     fontconfig-2.14.2          |       h82840c6_0         232 KB  conda-forge
#     freexl-2.0.0               |       ha3de405_0          52 KB
#     gdal-3.6.2                 |  py312h5ed0132_4         1.6 MB
#     geopandas-0.14.4           |     pyhd8ed1ab_0           8 KB  conda-forge
#     geopandas-base-0.14.4      |     pyha770c72_0         997 KB  conda-forge
#     geos-3.9.1                 |       h9f76cd9_2         872 KB  conda-forge
#     geotiff-1.7.0              |       h41f0982_3         128 KB
#     hdf4-4.2.13                |    h0ef36ac_1005         875 KB  conda-forge
#     json-c-0.16                |       hc449e50_0          72 KB  conda-forge
#     kealib-1.5.0               |       hba2eb73_1         144 KB
#     libboost-headers-1.82.0    |       hce30654_6        13.2 MB  conda-forge
#     libcxx-19.1.6              |       ha82da77_1         509 KB  conda-forge
#     libgdal-3.6.2              |       h0413ea8_4         8.3 MB
#     libkml-1.3.0               |    h1eb4d9f_1018         411 KB  conda-forge
#     libnetcdf-4.8.1            |       h0fce390_4         1.1 MB
#     libspatialite-5.1.0        |       h87e580a_0         3.8 MB
#     libzip-1.10.1              |       ha0bc3c6_3         125 KB  conda-forge
#     mapclassify-2.8.1          |     pyhd8ed1ab_1          55 KB  conda-forge
#     matplotlib-3.10.0          |  py312h1f38498_0          17 KB  conda-forge
#     matplotlib-base-3.10.0     |  py312hdbc7e53_0         7.6 MB  conda-forge
#     minizip-4.0.3              |       ha89c15f_0          84 KB
#     nspr-4.36                  |       h5833ebf_0         198 KB  conda-forge
#     nss-3.100                  |       hc6e9f88_0         1.8 MB  conda-forge
#     pandas-2.2.3               |  py312hcd31e36_1        13.8 MB  conda-forge
#     pixman-0.44.2              |       h2f9eb0b_0         196 KB  conda-forge
#     poppler-22.12.0            |       h52f4003_3         1.6 MB
#     poppler-data-0.4.12        |       hd8ed1ab_0         2.2 MB  conda-forge
#     proj-9.3.1                 |       h805f6d4_0         2.8 MB
#     pyproj-3.6.1               |  py312h4d912e0_5         474 KB  conda-forge
#     qhull-2020.2               |       h420ef59_5         504 KB  conda-forge
#     seaborn-0.13.2             |       hd8ed1ab_3           7 KB  conda-forge
#     seaborn-base-0.13.2        |     pyhd8ed1ab_3         223 KB  conda-forge
#     shapely-2.0.5              |  py312ha8c8ce4_0         551 KB
#     streamlit-1.41.1           |     pyhd8ed1ab_1         7.1 MB  conda-forge
#     tiledb-2.3.3               |       hb4a6b97_3         2.3 MB
#     tzlocal-5.2                |  py312h81bd7bf_1          40 KB  conda-forge
#     uriparser-0.9.8            |       h00cdb27_0          40 KB  conda-forge
#     xerces-c-3.2.4             |       h313beb8_1         2.2 MB
#     ------------------------------------------------------------
#                                            Total:        79.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   branca             conda-forge/noarch::branca-0.8.1-pyhd8ed1ab_0
#   cairo              pkgs/main/osx-arm64::cairo-1.16.0-h302bd0f_5
#   click-plugins      conda-forge/noarch::click-plugins-1.1.1-pyhd8ed1ab_1
#   cligj              conda-forge/noarch::cligj-0.7.2-pyhd8ed1ab_2
#   fiona              pkgs/main/osx-arm64::fiona-1.9.5-py312hd77ebd4_0
#   folium             conda-forge/noarch::folium-0.19.2-pyhd8ed1ab_0
#   fontconfig         conda-forge/osx-arm64::fontconfig-2.14.2-h82840c6_0
#   freexl             pkgs/main/osx-arm64::freexl-2.0.0-ha3de405_0
#   gdal               pkgs/main/osx-arm64::gdal-3.6.2-py312h5ed0132_4
#   geopandas          conda-forge/noarch::geopandas-0.14.4-pyhd8ed1ab_0
#   geopandas-base     conda-forge/noarch::geopandas-base-0.14.4-pyha770c72_0
#   geos               conda-forge/osx-arm64::geos-3.9.1-h9f76cd9_2
#   geotiff            pkgs/main/osx-arm64::geotiff-1.7.0-h41f0982_3
#   hdf4               conda-forge/osx-arm64::hdf4-4.2.13-h0ef36ac_1005
#   json-c             conda-forge/osx-arm64::json-c-0.16-hc449e50_0
#   kealib             pkgs/main/osx-arm64::kealib-1.5.0-hba2eb73_1
#   libboost-headers   conda-forge/osx-arm64::libboost-headers-1.82.0-hce30654_6
#   libgdal            pkgs/main/osx-arm64::libgdal-3.6.2-h0413ea8_4
#   libkml             conda-forge/osx-arm64::libkml-1.3.0-h1eb4d9f_1018
#   libnetcdf          pkgs/main/osx-arm64::libnetcdf-4.8.1-h0fce390_4
#   libspatialite      pkgs/main/osx-arm64::libspatialite-5.1.0-h87e580a_0
#   libzip             conda-forge/osx-arm64::libzip-1.10.1-ha0bc3c6_3
#   mapclassify        conda-forge/noarch::mapclassify-2.8.1-pyhd8ed1ab_1
#   minizip            pkgs/main/osx-arm64::minizip-4.0.3-ha89c15f_0
#   nspr               conda-forge/osx-arm64::nspr-4.36-h5833ebf_0
#   nss                conda-forge/osx-arm64::nss-3.100-hc6e9f88_0
#   pixman             conda-forge/osx-arm64::pixman-0.44.2-h2f9eb0b_0
#   poppler            pkgs/main/osx-arm64::poppler-22.12.0-h52f4003_3
#   poppler-data       conda-forge/noarch::poppler-data-0.4.12-hd8ed1ab_0
#   proj               pkgs/main/osx-arm64::proj-9.3.1-h805f6d4_0
#   pyproj             conda-forge/osx-arm64::pyproj-3.6.1-py312h4d912e0_5
#   qhull              conda-forge/osx-arm64::qhull-2020.2-h420ef59_5
#   seaborn-base       conda-forge/noarch::seaborn-base-0.13.2-pyhd8ed1ab_3
#   shapely            pkgs/main/osx-arm64::shapely-2.0.5-py312ha8c8ce4_0
#   tiledb             pkgs/main/osx-arm64::tiledb-2.3.3-hb4a6b97_3
#   tzlocal            conda-forge/osx-arm64::tzlocal-5.2-py312h81bd7bf_1
#   uriparser          conda-forge/osx-arm64::uriparser-0.9.8-h00cdb27_0
#   xerces-c           pkgs/main/osx-arm64::xerces-c-3.2.4-h313beb8_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2024.9.24-~ --> conda-forge::ca-certificates-2024.12.14-hf0a4a13_0
#   certifi                            2024.8.30-pyhd8ed1ab_0 --> 2024.12.14-pyhd8ed1ab_0
#   conda                             24.11.0-py312h81bd7bf_0 --> 24.11.1-py312h81bd7bf_0
#   libcxx                pkgs/main::libcxx-14.0.6-h848a8c0_0 --> conda-forge::libcxx-19.1.6-ha82da77_1
#   matplotlib         pkgs/main::matplotlib-3.8.4-py312hca0~ --> conda-forge::matplotlib-3.10.0-py312h1f38498_0
#   matplotlib-base    pkgs/main::matplotlib-base-3.8.4-py31~ --> conda-forge::matplotlib-base-3.10.0-py312hdbc7e53_0
#   pandas             pkgs/main::pandas-2.2.2-py312hd77ebd4~ --> conda-forge::pandas-2.2.3-py312hcd31e36_1
#   seaborn            pkgs/main/osx-arm64::seaborn-0.13.2-p~ --> conda-forge/noarch::seaborn-0.13.2-hd8ed1ab_3
#   streamlit          pkgs/main/osx-arm64::streamlit-1.32.0~ --> conda-forge/noarch::streamlit-1.41.1-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages:
# pandas-2.2.3         | 13.8 MB   |                                       |   0%
# libboost-headers-1.8 | 13.2 MB   |                                       |   0%
#
# libgdal-3.6.2        | 8.3 MB    |                                       |   0%
#
#
# matplotlib-base-3.10 | 7.6 MB    |                                       |   0%
#
#
#
# streamlit-1.41.1     | 7.1 MB    |                                       |   0%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    |                                       |   0%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    |                                       |   0%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    |                                       |   0%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# nss-3.100            | 1.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.1        | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-19.1.6        | 509 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# streamlit-1.41.1     | 7.1 MB    |                                       |   0%
# libboost-headers-1.8 | 13.2 MB   |                                       |   0%
#
#
# pandas-2.2.3         | 13.8 MB   |                                       |   0%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | 6                                     |   2%
# libboost-headers-1.8 | 13.2 MB   | 3                                     |   1%
#
#
# matplotlib-base-3.10 | 7.6 MB    | 6                                     |   2%
#
# pandas-2.2.3         | 13.8 MB   | 3                                     |   1%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | 8                                     |   2%
# libboost-headers-1.8 | 13.2 MB   | 7                                     |   2%
#
#
# pandas-2.2.3         | 13.8 MB   | 9                                     |   3%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ###2                                  |   9%
# libboost-headers-1.8 | 13.2 MB   | #3                                    |   4%
#
# pandas-2.2.3         | 13.8 MB   | #4                                    |   4%
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##                                    |   6%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##                                    |   6%
#
# libgdal-3.6.2        | 8.3 MB    | 8                                     |   2%
# pandas-2.2.3         | 13.8 MB   | ##4                                   |   7%
#
# libgdal-3.6.2        | 8.3 MB    | #5                                    |   4%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##4                                   |   7%
# libboost-headers-1.8 | 13.2 MB   | ##6                                   |   7%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #####1                                |  14%
#
#
# pandas-2.2.3         | 13.8 MB   | ###                                   |   8%
#
# libgdal-3.6.2        | 8.3 MB    | #9                                    |   5%
# libboost-headers-1.8 | 13.2 MB   | ###1                                  |   8%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #####9                                |  16%
#
# pandas-2.2.3         | 13.8 MB   | ###4                                  |   9%
# libboost-headers-1.8 | 13.2 MB   | ###5                                  |  10%
#
#
# pandas-2.2.3         | 13.8 MB   | ###9                                  |  11%
#
# libgdal-3.6.2        | 8.3 MB    | ###4                                  |   9%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #####6                                |  15%
# libboost-headers-1.8 | 13.2 MB   | ###9                                  |  11%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #######6                              |  21%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ######4                               |  17%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #######1                              |  19%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ########9                             |  24%
# libboost-headers-1.8 | 13.2 MB   | ####3                                 |  12%
#
# libgdal-3.6.2        | 8.3 MB    | ###9                                  |  11%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #######9                              |  21%
#
#
#
# pandas-2.2.3         | 13.8 MB   | ####3                                 |  12%
# libboost-headers-1.8 | 13.2 MB   | #####4                                |  15%
#
# libgdal-3.6.2        | 8.3 MB    | ####3                                 |  12%
#
#
#
# pandas-2.2.3         | 13.8 MB   | #####6                                |  15%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########6                             |  23%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ###########4                          |  31%
# pandas-2.2.3         | 13.8 MB   | ######1                               |  17%
#
# libgdal-3.6.2        | 8.3 MB    | #####9                                |  16%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #########3                            |  25%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ############2                         |  33%
# pandas-2.2.3         | 13.8 MB   | ######5                               |  18%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #########9                            |  27%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ############9                         |  35%
#
# libgdal-3.6.2        | 8.3 MB    | ######3                               |  17%
# libboost-headers-1.8 | 13.2 MB   | ######4                               |  17%
#
#
# pandas-2.2.3         | 13.8 MB   | ######9                               |  19%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #############6                        |  37%
# libboost-headers-1.8 | 13.2 MB   | ######7                               |  18%
#
# libgdal-3.6.2        | 8.3 MB    | ######8                               |  18%
#
#
# pandas-2.2.3         | 13.8 MB   | #######3                              |  20%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ##############4                       |  39%
# libboost-headers-1.8 | 13.2 MB   | #######                               |  19%
#
# pandas-2.2.3         | 13.8 MB   | #######7                              |  21%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ###########6                          |  31%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ###############2                      |  41%
# libboost-headers-1.8 | 13.2 MB   | #######4                              |  20%
#
# pandas-2.2.3         | 13.8 MB   | ########                              |  22%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ################1                     |  44%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ############1                         |  33%
# libboost-headers-1.8 | 13.2 MB   | #######8                              |  21%
#
# pandas-2.2.3         | 13.8 MB   | ########5                             |  23%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ############7                         |  35%
# libboost-headers-1.8 | 13.2 MB   | ########2                             |  22%
#
# libgdal-3.6.2        | 8.3 MB    | ########6                             |  23%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ################8                     |  46%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #############3                        |  36%
# libboost-headers-1.8 | 13.2 MB   | ########5                             |  23%
#
# pandas-2.2.3         | 13.8 MB   | ########8                             |  24%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #################5                    |  47%
#
# pandas-2.2.3         | 13.8 MB   | #########2                            |  25%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #############9                        |  38%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ##################2                   |  49%
# libboost-headers-1.8 | 13.2 MB   | ########9                             |  24%
#
# libgdal-3.6.2        | 8.3 MB    | #########8                            |  27%
#
#
# pandas-2.2.3         | 13.8 MB   | #########5                            |  26%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ##################8                   |  51%
# libboost-headers-1.8 | 13.2 MB   | #########2                            |  25%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ###############1                      |  41%
#
# pandas-2.2.3         | 13.8 MB   | #########8                            |  27%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ###################5                  |  53%
# libboost-headers-1.8 | 13.2 MB   | #########5                            |  26%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ###############7                      |  43%
#
# pandas-2.2.3         | 13.8 MB   | ##########2                           |  28%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ####################1                 |  54%
# pandas-2.2.3         | 13.8 MB   | ##########6                           |  29%
#
# libgdal-3.6.2        | 8.3 MB    | ###########2                          |  30%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ################4                     |  44%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ####################8                 |  56%
# pandas-2.2.3         | 13.8 MB   | ###########                           |  30%
#
# libgdal-3.6.2        | 8.3 MB    | ###########6                          |  32%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #################                     |  46%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #####################4                |  58%
# pandas-2.2.3         | 13.8 MB   | ###########3                          |  31%
#
# libgdal-3.6.2        | 8.3 MB    | ############2                         |  33%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #################6                    |  48%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ######################                |  60%
# pandas-2.2.3         | 13.8 MB   | ###########8                          |  32%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##################2                   |  49%
#
# libgdal-3.6.2        | 8.3 MB    | ############7                         |  34%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ######################7               |  61%
# libboost-headers-1.8 | 13.2 MB   | ###########1                          |  30%
#
# libgdal-3.6.2        | 8.3 MB    | #############2                        |  36%
#
#
# pandas-2.2.3         | 13.8 MB   | ############2                         |  33%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #######################3              |  63%
# libboost-headers-1.8 | 13.2 MB   | ###########4                          |  31%
#
# libgdal-3.6.2        | 8.3 MB    | #############7                        |  37%
#
#
# pandas-2.2.3         | 13.8 MB   | ############6                         |  34%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ########################              |  65%
# libboost-headers-1.8 | 13.2 MB   | ###########7                          |  32%
#
# libgdal-3.6.2        | 8.3 MB    | ##############2                       |  39%
#
#
# pandas-2.2.3         | 13.8 MB   | #############                         |  35%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ########################7             |  67%
# libboost-headers-1.8 | 13.2 MB   | ############                          |  33%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ####################4                 |  55%
#
# pandas-2.2.3         | 13.8 MB   | #############4                        |  36%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #########################4            |  69%
# libboost-headers-1.8 | 13.2 MB   | ############3                         |  33%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ####################9                 |  57%
#
# libgdal-3.6.2        | 8.3 MB    | ###############3                      |  42%
#
#
#
# pandas-2.2.3         | 13.8 MB   | #############8                        |  37%
# libboost-headers-1.8 | 13.2 MB   | ############6                         |  34%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #####################6                |  58%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ##########################5           |  72%
#
# pandas-2.2.3         | 13.8 MB   | ##############2                       |  38%
# libboost-headers-1.8 | 13.2 MB   | #############                         |  35%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ######################2               |  60%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ###########################1          |  73%
#
# libgdal-3.6.2        | 8.3 MB    | ################3                     |  44%
# pandas-2.2.3         | 13.8 MB   | ##############6                       |  40%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ######################7               |  61%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ###########################6          |  75%
#
# libgdal-3.6.2        | 8.3 MB    | ################8                     |  45%
# pandas-2.2.3         | 13.8 MB   | ###############                       |  41%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #######################5              |  64%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ############################2         |  76%
#
# pandas-2.2.3         | 13.8 MB   | ###############4                      |  42%
# libboost-headers-1.8 | 13.2 MB   | ##############                        |  38%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########################1             |  65%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ############################8         |  78%
#
# pandas-2.2.3         | 13.8 MB   | ###############7                      |  43%
# libboost-headers-1.8 | 13.2 MB   | ##############3                       |  39%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########################6             |  67%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #############################3        |  79%
#
# pandas-2.2.3         | 13.8 MB   | ################1                     |  44%
# libboost-headers-1.8 | 13.2 MB   | ##############6                       |  40%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | #############################9        |  81%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #########################2            |  68%
#
# pandas-2.2.3         | 13.8 MB   | ################4                     |  44%
# libboost-headers-1.8 | 13.2 MB   | ##############9                       |  40%
#
#
# matplotlib-base-3.10 | 7.6 MB    | #########################7            |  70%
#
#
#
# pandas-2.2.3         | 13.8 MB   | ################7                     |  45%
#
# libgdal-3.6.2        | 8.3 MB    | ###################2                  |  52%
# libboost-headers-1.8 | 13.2 MB   | ###############2                      |  41%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##########################3           |  71%
#
#
#
# pandas-2.2.3         | 13.8 MB   | #################1                    |  46%
#
# libgdal-3.6.2        | 8.3 MB    | ###################7                  |  53%
# libboost-headers-1.8 | 13.2 MB   | ###############5                      |  42%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##########################9           |  73%
#
#
#
# pandas-2.2.3         | 13.8 MB   | #################5                    |  47%
#
# libgdal-3.6.2        | 8.3 MB    | ####################2                 |  55%
# libboost-headers-1.8 | 13.2 MB   | ###############9                      |  43%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ###########################5          |  75%
#
#
#
# pandas-2.2.3         | 13.8 MB   | #################8                    |  48%
#
# libgdal-3.6.2        | 8.3 MB    | ####################7                 |  56%
# libboost-headers-1.8 | 13.2 MB   | ################2                     |  44%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ############################1         |  76%
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##################1                   |  49%
#
# libgdal-3.6.2        | 8.3 MB    | #####################2                |  57%
# libboost-headers-1.8 | 13.2 MB   | ################5                     |  45%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ############################8         |  78%
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##################5                   |  50%
#
# libgdal-3.6.2        | 8.3 MB    | #####################7                |  59%
# libboost-headers-1.8 | 13.2 MB   | ################8                     |  45%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ##################################1   |  92%
#
#
# pandas-2.2.3         | 13.8 MB   | ##################8                   |  51%
#
# libgdal-3.6.2        | 8.3 MB    | ######################1               |  60%
# libboost-headers-1.8 | 13.2 MB   | #################1                    |  46%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ##################################7   |  94%
#
#
# pandas-2.2.3         | 13.8 MB   | ###################2                  |  52%
#
# libgdal-3.6.2        | 8.3 MB    | ######################6               |  61%
# libboost-headers-1.8 | 13.2 MB   | #################4                    |  47%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ###################################3  |  96%
#
#
# pandas-2.2.3         | 13.8 MB   | ###################6                  |  53%
#
# libgdal-3.6.2        | 8.3 MB    | #######################1              |  63%
# libboost-headers-1.8 | 13.2 MB   | #################7                    |  48%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ####################################  |  97%
#
#
# pandas-2.2.3         | 13.8 MB   | ###################9                  |  54%
#
# libgdal-3.6.2        | 8.3 MB    | #######################6              |  64%
# libboost-headers-1.8 | 13.2 MB   | ##################1                   |  49%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ####################################5 |  99%
#
#
# pandas-2.2.3         | 13.8 MB   | ####################3                 |  55%
#
# libgdal-3.6.2        | 8.3 MB    | ########################1             |  65%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ##################4                   |  50%
#
#
# pandas-2.2.3         | 13.8 MB   | ####################7                 |  56%
#
# libgdal-3.6.2        | 8.3 MB    | ########################6             |  67%
# libboost-headers-1.8 | 13.2 MB   | ##################8                   |  51%
#
#
# pandas-2.2.3         | 13.8 MB   | #####################1                |  57%
#
#
#
# streamlit-1.41.1     | 7.1 MB    | ##################################### | 100%
#
# libgdal-3.6.2        | 8.3 MB    | #########################2            |  68%
# libboost-headers-1.8 | 13.2 MB   | ###################3                  |  52%
#
#
# pandas-2.2.3         | 13.8 MB   | #####################4                |  58%
#
# libgdal-3.6.2        | 8.3 MB    | #########################8            |  70%
# libboost-headers-1.8 | 13.2 MB   | ###################7                  |  53%
#
#
# pandas-2.2.3         | 13.8 MB   | #####################8                |  59%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | 1                                     |   0%
#
# libgdal-3.6.2        | 8.3 MB    | ##########################2           |  71%
# libboost-headers-1.8 | 13.2 MB   | ####################1                 |  54%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ###################################5  |  96%
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ######################2               |  60%
#
# libgdal-3.6.2        | 8.3 MB    | ##########################7           |  72%
# libboost-headers-1.8 | 13.2 MB   | ####################4                 |  55%
#
#
# pandas-2.2.3         | 13.8 MB   | ######################5               |  61%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | #9                                    |   5%
#
# libgdal-3.6.2        | 8.3 MB    | ###########################2          |  74%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | #####3                                |  14%
# libboost-headers-1.8 | 13.2 MB   | ####################8                 |  56%
#
#
# pandas-2.2.3         | 13.8 MB   | ######################9               |  62%
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##################################### | 100%
#
# libgdal-3.6.2        | 8.3 MB    | ###########################8          |  75%
# libboost-headers-1.8 | 13.2 MB   | #####################2                |  57%
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | #######################2              |  63%
#
# libgdal-3.6.2        | 8.3 MB    | ############################3         |  77%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | #########2                            |  25%
# libboost-headers-1.8 | 13.2 MB   | #####################6                |  58%
#
#
# pandas-2.2.3         | 13.8 MB   | #######################5              |  64%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | ###########2                          |  30%
#
# libgdal-3.6.2        | 8.3 MB    | ############################7         |  78%
# pandas-2.2.3         | 13.8 MB   | #######################8              |  65%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | #############                         |  35%
#
# libgdal-3.6.2        | 8.3 MB    | #############################2        |  79%
# pandas-2.2.3         | 13.8 MB   | ########################1             |  65%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | 2                                     |   1%
#
# libgdal-3.6.2        | 8.3 MB    | #############################6        |  80%
# libboost-headers-1.8 | 13.2 MB   | ######################6               |  61%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | ################2                     |  44%
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ########################4             |  66%
# libboost-headers-1.8 | 13.2 MB   | ######################9               |  62%
#
# libgdal-3.6.2        | 8.3 MB    | ##############################        |  81%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | ###################5                  |  53%
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ########################8             |  67%
#
# libgdal-3.6.2        | 8.3 MB    | ##############################5       |  83%
# libboost-headers-1.8 | 13.2 MB   | #######################3              |  63%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | #####################5                |  58%
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | #########################1            |  68%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | #######################7              |  64%
# libboost-headers-1.8 | 13.2 MB   | #######################6              |  64%
#
# libgdal-3.6.2        | 8.3 MB    | ##############################9       |  84%
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | #########################4            |  69%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | #########################7            |  70%
# libboost-headers-1.8 | 13.2 MB   | #######################9              |  65%
#
# libgdal-3.6.2        | 8.3 MB    | ###############################2      |  85%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | ###########6                          |  32%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | ###########################7          |  75%
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | #########################6            |  69%
#
# libgdal-3.6.2        | 8.3 MB    | ###############################6      |  86%
# libboost-headers-1.8 | 13.2 MB   | ########################2             |  66%
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | #########################9            |  70%
#
# libgdal-3.6.2        | 8.3 MB    | ###############################9      |  86%
# libboost-headers-1.8 | 13.2 MB   | ########################5             |  66%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | ################4                     |  44%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | ################################1     |  87%
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##########################1           |  71%
#
# libgdal-3.6.2        | 8.3 MB    | ################################3     |  87%
# libboost-headers-1.8 | 13.2 MB   | ########################7             |  67%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | ######################                |  60%
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##########################3           |  71%
#
# libgdal-3.6.2        | 8.3 MB    | ################################6     |  88%
# libboost-headers-1.8 | 13.2 MB   | #########################             |  68%
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##########################5           |  72%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | ##################################### | 100%
#
# libgdal-3.6.2        | 8.3 MB    | #################################1    |  89%
# libboost-headers-1.8 | 13.2 MB   | #########################3            |  69%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | ########################5             |  66%
#
#
#
#
# libspatialite-5.1.0  | 3.8 MB    | ##################################### | 100%
#
# libgdal-3.6.2        | 8.3 MB    | #################################4    |  90%
# pandas-2.2.3         | 13.8 MB   | ##########################9           |  73%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | ############################3         |  77%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | 2                                     |   1%
#
# pandas-2.2.3         | 13.8 MB   | ###########################2          |  74%
# libboost-headers-1.8 | 13.2 MB   | ##########################            |  70%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | ###############################       |  84%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ###4                                  |   9%
# libboost-headers-1.8 | 13.2 MB   | ##########################3           |  71%
#
# pandas-2.2.3         | 13.8 MB   | ###########################5          |  74%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #######1                              |  19%
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ###########################7          |  75%
# libboost-headers-1.8 | 13.2 MB   | ##########################6           |  72%
#
# libgdal-3.6.2        | 8.3 MB    | ##################################7   |  94%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ##########6                           |  29%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | ###################################6  |  96%
# pandas-2.2.3         | 13.8 MB   | ############################          |  76%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #############5                        |  37%
#
# libgdal-3.6.2        | 8.3 MB    | ###################################   |  95%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #################5                    |  47%
# pandas-2.2.3         | 13.8 MB   | ############################2         |  76%
#
#
#
#
#
# proj-9.3.1           | 2.8 MB    | ##################################### | 100%
#
# pandas-2.2.3         | 13.8 MB   | ############################5         |  77%
#
# libgdal-3.6.2        | 8.3 MB    | ###################################7  |  97%
# libboost-headers-1.8 | 13.2 MB   | ###########################5          |  75%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ####################9                 |  57%
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ############################7         |  78%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ########################1             |  65%
# libboost-headers-1.8 | 13.2 MB   | ###########################9          |  75%
#
# libgdal-3.6.2        | 8.3 MB    | ####################################1 |  98%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##                                    |   6%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ####9                                 |  13%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ###########################3          |  74%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ###############################3      |  85%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ########5                             |  23%
#
# libgdal-3.6.2        | 8.3 MB    | ####################################5 |  99%
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | #############################         |  78%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ###################################4  |  96%
# libboost-headers-1.8 | 13.2 MB   | ############################2         |  76%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ##################################### | 100%
#
# pandas-2.2.3         | 13.8 MB   | #############################3        |  79%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ###############4                      |  42%
#
# libgdal-3.6.2        | 8.3 MB    | ##################################### | 100%
#
#
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ##################################### | 100%
# pandas-2.2.3         | 13.8 MB   | #############################6        |  80%
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | 2                                     |   1%
#
# libgdal-3.6.2        | 8.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##################8                   |  51%
# pandas-2.2.3         | 13.8 MB   | #############################9        |  81%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ######################4               |  61%
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ###9                                  |  11%
# libboost-headers-1.8 | 13.2 MB   | #############################2        |  79%
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##############################1       |  82%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | #########################8            |  70%
# libboost-headers-1.8 | 13.2 MB   | #############################5        |  80%
#
#
#
#
#
#
#
#
#
# nss-3.100            | 1.8 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##############################4       |  82%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ############################9         |  78%
# libboost-headers-1.8 | 13.2 MB   | #############################8        |  81%
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ##############4                       |  39%
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##############################6       |  83%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ################################      |  87%
# libboost-headers-1.8 | 13.2 MB   | ##############################1       |  81%
#
#
#
#
#
#
#
#
#
# nss-3.100            | 1.8 MB    | ######5                               |  18%
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | #################8                    |  48%
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##############################9       |  84%
# libboost-headers-1.8 | 13.2 MB   | ##############################4       |  82%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
# nss-3.100            | 1.8 MB    | ############4                         |  34%
#
#
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ##############################6       |  83%
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
# nss-3.100            | 1.8 MB    | ###################6                  |  53%
# libboost-headers-1.8 | 13.2 MB   | ##############################8       |  83%
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | 3                                     |   1%
# libboost-headers-1.8 | 13.2 MB   | ###############################       |  84%
#
#
#
#
#
#
#
#
#
# nss-3.100            | 1.8 MB    | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | #####3                                |  14%
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ###############################7      |  86%
# libboost-headers-1.8 | 13.2 MB   | ###############################2      |  85%
#
#
#
#
#
#
#
#
#
# nss-3.100            | 1.8 MB    | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
# nss-3.100            | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ###############################9      |  86%
# libboost-headers-1.8 | 13.2 MB   | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
# nss-3.100            | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ################################2     |  87%
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | #################7                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ################################4     |  88%
#
#
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ################################1     |  87%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ################################7     |  89%
# libboost-headers-1.8 | 13.2 MB   | ################################3     |  88%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ################################9     |  89%
# libboost-headers-1.8 | 13.2 MB   | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ###############################5      |  85%
# pandas-2.2.3         | 13.8 MB   | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.1        | 1.1 MB    | #######7                              |  21%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #########2                            |  25%
#
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ##################################### | 100%
# pandas-2.2.3         | 13.8 MB   | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.1        | 1.1 MB    | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ##################################### | 100%
# pandas-2.2.3         | 13.8 MB   | #################################8    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.1        | 1.1 MB    | ################                      |  43%
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##################################1   |  92%
# libboost-headers-1.8 | 13.2 MB   | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.1        | 1.1 MB    | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #################                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | 5                                     |   1%
# pandas-2.2.3         | 13.8 MB   | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.1        | 1.1 MB    | ########################7             |  67%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###################6                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | #####4                                |  15%
# libboost-headers-1.8 | 13.2 MB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ######################1               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ###########5                          |  31%
# libboost-headers-1.8 | 13.2 MB   | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##################################9   |  95%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ########################7             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | #################                     |  46%
# libboost-headers-1.8 | 13.2 MB   | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.1        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##########################9           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | #######################               |  62%
# pandas-2.2.3         | 13.8 MB   | ###################################5  |  96%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.1        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ############################5         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | 5                                     |   2%
# pandas-2.2.3         | 13.8 MB   | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ################################1     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ##################################### | 100%
# pandas-2.2.3         | 13.8 MB   | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##############1                       |  38%
# pandas-2.2.3         | 13.8 MB   | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ####################3                 |  55%
#
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################################### | 100%
# pandas-2.2.3         | 13.8 MB   | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##########################            |  70%
# libboost-headers-1.8 | 13.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ################                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | #############7                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | ###################6                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | ######################5               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | ########################8             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ###################6                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ##############9                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-19.1.6        | 509 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | #########################7            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ###################6                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-19.1.6        | 509 KB    | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ########################4             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-19.1.6        | 509 KB    | #############################         |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ############################5         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-19.1.6        | 509 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-19.1.6        | 509 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.3         | 13.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
code = """
import pandas as pd

def calculate_avg_distance(df):
    try:
        # Calculate national averages
        avg_distance_national = df['Distance (km)'].mean() if 'Distance (km)' in df.columns else None
        avg_travel_time_national = df['Duration (minutes)'].mean() if 'Duration (minutes)' in df.columns else None
        
        # Calculate state averages
        avg_distance_state = df.groupby('state')['Distance (km)'].mean() if 'Distance (km)' in df.columns else pd.Series()
        avg_travel_time_state = df.groupby('state')['Duration (minutes)'].mean() if 'Duration (minutes)' in df.columns else pd.Series()
        
        return avg_distance_national, avg_travel_time_national, avg_distance_state, avg_travel_time_state
    except Exception as e:
        print(f"Error in calculate_avg_distance: {e}")
        return None, None, None, None

def most_typical_incident(df):
    # National-level most typical incident (string)
    most_typical_national = df['incidentType'].mode()[0] if not df['incidentType'].mode().empty else None
    
    # State-level most typical incident (pandas Series)
    most_typical_state = df.groupby('state')['incidentType'].agg(lambda x: x.mode()[0] if not x.mode().empty else None)
    
    return most_typical_national, most_typical_state


def most_utilized_hubs(df):
    # National-level most utilized EOC (string)
    most_utilized_national = df['EOC'].mode()[0] if not df['EOC'].mode().empty else None
    
    # State-level most utilized EOC (pandas Series)
    most_utilized_state = df.groupby('state')['EOC'].agg(lambda x: x.mode()[0] if not x.mode().empty else None)
    
    return most_utilized_national, most_utilized_state """

# Write the functions to a .py file
with open('fema_functions.py', 'w') as f:
    f.write(code)

# %%
import streamlit as st
import pandas as pd
from fema_functions import calculate_avg_distance, most_typical_incident, most_utilized_hubs

# Load the FEMA dataset (adjust the path as necessary)
fema_df = pd.read_csv('data/clean/fema_df_coords.csv')

# Title and Description
st.title("U.S. Disaster Response Management")
st.write("This app provides insights into the Emergency Operations Center (EOC) network and disaster response efficiency.")

# National Insights Section
st.header("National Insights")

# Calculate National Metrics
avg_distance_national, avg_travel_time_national, _, _ = calculate_avg_distance(fema_df)
most_typical_national, _ = most_typical_incident(fema_df)
most_utilized_national, _ = most_utilized_hubs(fema_df)

# Display National Metrics
st.subheader("Key Metrics")

st.metric("Average Response Time (National)", f"{avg_travel_time_national:.2f} hours")
st.metric("Average Distance to Disaster (National)", f"{avg_distance_national:.2f} miles")
# Interactive Widgets for State-Level Insights
st.header("Insights by State")

# Selectbox to choose a state
state = st.selectbox("Select a state:", fema_df['state'].unique())
st.write(f"You selected: {state}")

# Filter data for the selected state
state_df = fema_df[fema_df['state'] == state]

# Calculate State-Level Metrics
avg_distance_national, avg_travel_time_national, avg_distance_state, avg_travel_time_state = calculate_avg_distance(state_df)
most_typical_state, _ = most_typical_incident(state_df)
most_utilized_state, _ = most_utilized_hubs(state_df)

# Display State-Level Metrics
st.subheader(f"Key Metrics for {state}")
st.metric("Average Response Time (State)", f"{avg_travel_time_state[state]:.2f} hours")
st.metric("Average Distance to Disaster (State)", f"{avg_distance_state[state]:.2f} miles")
state = st.selectbox("Select a state:", fema_df['state'].unique())


# Placeholder for Visualizations
st.header("Visualizations")
st.write("Here, you can upload or display visualizations of the data, such as maps, charts, or graphs related to disaster response efficiency.")
# Out:
# 2024-12-19 13:45:00.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-19 13:45:00.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
